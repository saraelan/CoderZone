# %% [markdown]
# ### Objective

# %% [raw]
# Learn how to connect to social media network (we will use Twitter as example in this assignment), and collect/preprocess/analyze its data
#
#
# Tweets Data Can be used for different purposes by marketing department and data analytics team. For example:
#
# - Compete with rivals to offer price-match gaurantee policy
# - Offer same coupons like rivals in the market place

# %% [markdown]
# ### Installation and Setup

# %% [raw]
# For this assignment you need to do the following setup first:
#
# 1.  Create an account on twitter.com.
#
# 2.  Generate authentication tokens by following the instructions here :
#     https://dev.twitter.com/oauth/overview/application-owner-access-tokens
#
# 3.  Add your tokens to the credentials.txt file.

# %% [markdown]
# ### Twitter API

# %% [raw]
# Twitter API
#
# Two APIs:
#
#     REST API: Submit HTTP requests to access specific information (tweets, friends, ...)
#     Streaming API: Open a continuous connection to Twitter to receive real-time data.
#
# These APIs are  HTTP GET request
#
#
#
#
# Here are the twitter API docs that you must familiarize yourself with
#
# https://dev.twitter.com/rest/reference/get/followers/ids
#
# https://dev.twitter.com/overview/api/twitter-libraries

# %% [raw]
# When you search in a text (tweets are text messages), often you need to be aware of something STOP WORDS.
# You could read more about stop-words here:
#
#     https://en.wikipedia.org/wiki/Stop_words

# %% [markdown]
# # Lets create twitter object and use its API. Code snippets below will show you how to use this API

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterPager

# %%
o = TwitterOAuth.read_file(r'C:\apache-tomcat-7.0.34\webapps\CricInfo\credentials.txt')

# %%
o.access_token_key
# Out:
# '1058753351050018817-vdNLxtwWzh2y62yaN1B80ijJJqfJww'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(builtins.object)
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL string (ex. "https://USER:PASSWORD@SERVER:PORT"),
#  |                    or dict of URLs (ex. {'http':'http://SERVER', 'https':'https://SERVER'})
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A valid Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(resource, params=None, files=None, method_override=None) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A valid Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.
print(type(response))
dir(response)
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_quota',
#  'headers',
#  'json',
#  'response',
#  'status_code',
#  'stream',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x0000021CE4460668>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 200

# %%
tweets = [r for r in response]

# %%
print('found %d tweets' % len(tweets))
# Out:
# found 11 tweets

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[0]
# Out:
# {'created_at': 'Sat Nov 17 04:51:23 +0000 2018',
#  'id': 1063655817537339392,
#  'id_str': '1063655817537339392',
#  'text': 'RT @taniapsuv: Por favor lean esta historia de periodismo fantástico: https://t.co/QT6COU3D0Z  😱!! No saben que la Big Data ya registra con…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'taniapsuv',
#     'name': 'Tania Valentina Díaz',
#     'id': 173862310,
#     'id_str': '173862310',
#     'indices': [3, 13]}],
#   'urls': [{'url': 'https://t.co/QT6COU3D0Z',
#     'expanded_url': 'https://www.reuters.com/investigates/special-report/venezuela-zte-es/',
#     'display_url': 'reuters.com/investigates/s…',
#     'indices': [70, 93]}]},
#  'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 934642649386180610,
#   'id_str': '934642649386180610',
#   'name': 'Eduardo Perez',
#   'screen_name': 'EAPerezPsuv',
#   'location': 'Caracas, Venezuela',
#   'description': 'Conocí la mentira, la traición y los antivalores más viles de la humanidad. se los aseguro los vi a los ojos, no fue un sueño. #Cristiano #Venezolano #Chavista!',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 106,
#   'friends_count': 103,
#   'listed_count': 0,
#   'created_at': 'Sun Nov 26 04:39:07 +0000 2017',
#   'favourites_count': 623,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1080,
#   'lang': 'es',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1063557099484049409/57j6MnG4_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1063557099484049409/57j6MnG4_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/934642649386180610/1511671687',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': True,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Fri Nov 16 01:31:56 +0000 2018',
#   'id': 1063243235668168704,
#   'id_str': '1063243235668168704',
#   'text': 'Por favor lean esta historia de periodismo fantástico: https://t.co/QT6COU3D0Z  😱!! No saben que la Big Data ya reg… https://t.co/OGg8jkQ4K9',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/QT6COU3D0Z',
#      'expanded_url': 'https://www.reuters.com/investigates/special-report/venezuela-zte-es/',
#      'display_url': 'reuters.com/investigates/s…',
#      'indices': [55, 78]},
#     {'url': 'https://t.co/OGg8jkQ4K9',
#      'expanded_url': 'https://twitter.com/i/web/status/1063243235668168704',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 173862310,
#    'id_str': '173862310',
#    'name': 'Tania Valentina Díaz',
#    'screen_name': 'taniapsuv',
#    'location': 'Rep. Bolivariana de Venezuela',
#    'description': 'Orgullosa venezolana. Vicepresidenta de la Asamblea Nacional Constituyente. Guardiana del legado de Hugo Chávez',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 302537,
#    'friends_count': 2992,
#    'listed_count': 1168,
#    'created_at': 'Mon Aug 02 15:05:09 +0000 2010',
#    'favourites_count': 2718,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 34857,
#    'lang': 'es',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'EBEBEB',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1005309262590021632/Yn-JkZYq_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1005309262590021632/Yn-JkZYq_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/173862310/1528519382',
#    'profile_link_color': '990000',
#    'profile_sidebar_border_color': 'DFDFDF',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 354,
#   'favorite_count': 163,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'es'},
#  'is_quote_status': False,
#  'retweet_count': 354,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'es'}

# %%
help(tweets[0])
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
tweets[0]['text']
# Out:
# 'RT @taniapsuv: Por favor lean esta historia de periodismo fantástico: https://t.co/QT6COU3D0Z  😱!! No saben que la Big Data ya registra con…'

# %%
tweets[0]['created_at']
# Out:
# 'Sat Nov 17 04:51:23 +0000 2018'

# %%
tweets[0]['text']
# Out:
# 'RT @taniapsuv: Por favor lean esta historia de periodismo fantástico: https://t.co/QT6COU3D0Z  😱!! No saben que la Big Data ya registra con…'

# %%
tweets[0]['user']
# Out:
# {'id': 934642649386180610,
#  'id_str': '934642649386180610',
#  'name': 'Eduardo Perez',
#  'screen_name': 'EAPerezPsuv',
#  'location': 'Caracas, Venezuela',
#  'description': 'Conocí la mentira, la traición y los antivalores más viles de la humanidad. se los aseguro los vi a los ojos, no fue un sueño. #Cristiano #Venezolano #Chavista!',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 106,
#  'friends_count': 103,
#  'listed_count': 0,
#  'created_at': 'Sun Nov 26 04:39:07 +0000 2017',
#  'favourites_count': 623,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1080,
#  'lang': 'es',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1063557099484049409/57j6MnG4_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1063557099484049409/57j6MnG4_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/934642649386180610/1511671687',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': True,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))
# Out:
# screen_name=EAPerezPsuv, name=Eduardo Perez, location=Caracas, Venezuela

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print('found %d followers for %s' % (len(followers), screen_name))
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines
# Out:
# found 104 followers for EAPerezPsuv

# %%
print(followers[0]['screen_name'])
# Out:
# YoiraVargas

# %% [markdown]
# ##  Limitations:       Can only search 2 weeks in past         But can get up to 3,200 most recent tweets of a user     Rate limits! https://dev.twitter.com/docs/rate-limiting/1.1/limits         e.g., 180 requests in 15 minute window

# %% [markdown]
# # Get BestBuy timeline for the deals screen-name
#
# # This is the screen name for BestBuy_Deals

# %%
# Get BestBuyDeals timeline = ''
screen_name = ' CricketDirect'
timeline = [tweet for tweet in twitter.request('statuses/user_timeline',
                                                {'screen_name': screen_name,
                                                 'count': 200})]
print('got %d tweets for user %s' % (len(timeline), screen_name))
# Out:
# got 200 tweets for user  CricketDirect

# %%
# Print time got created.

timeline[3]['created_at']
# Out:
# 'Thu Nov 15 16:10:07 +0000 2018'

# %%
# Print the text.
print('\n\n\n'.join(t['text'] for t in timeline))
# Out:
# Puma Special Edition Gold is perfectly balanced to produce a combination of unrivaled pick-up and a devastating amo… https://t.co/qDFOYBiZm5
#
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/pKYAI6W01y
#
#
# The New Balance 2019 range has a striking combination of colours together with the large features on the bat again… https://t.co/RJ3XoC1WLT
#
#
# The Kookaburra Ghost Cricket Bat is an absolute monster – a giant profile with minimal sculpting, for players looki… https://t.co/RNQ4LTxMNF
#
#
# Save 40% on Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of pla… https://t.co/cMfMBYU3Pm
#
#
# Deliver your best performance with the new diamond range from Gunn and Moore. Designed to have a power arc bow, fee… https://t.co/pHKNJcqJp5
#
#
# Kookaburra Pro D3000 duffle cricket bag has an external bat sleeve for 2 bats, padded straps with an airflow mesh c… https://t.co/i5FP9iBlxx
#
#
# Puma Special Edition  is perfectly balanced to produce a combination of unrivaled pick-up and a devastating amount… https://t.co/GdGRDZSzRr
#
#
# Gray Nicolls Powerbow 6X has a powerful blade with a beguiling light pick-up.
# Armed with an unfailingly ability to… https://t.co/5l84Rd90Wh
#
#
# Adidas Adizero SL22 Boost is a cricket trainer that is perfect for training or batting on dry surfaces.… https://t.co/kJ5QH5Pmgc
#
#
# Gray-Nicolls Legend batting gloves has a multi-sectioned interlocking "V" design maximises flexibility and movement… https://t.co/Pc5IsrQR8h
#
#
# Reveal your dark side with the Gunn &amp; Moore Noir range. New to 2019, the profile is all about delivering menacing p… https://t.co/O7E4IrU7AY
#
#
# With the Kookaburra Rampage cricket bat there will be no shortage of boundaries with the new range. Just as the nam… https://t.co/ZF93gp6KW1
#
#
# Puma Special Edition white cricket bat features a powerful hitting zone, superior pick-up and exquisite balance.… https://t.co/APNJrcDEI2
#
#
# With a pronounced high-middle, full profile and intimidating edges, the Gray Nicolls Shockwave is a bat that will a… https://t.co/r9lBm5B99A
#
#
# Adidas Adipower Vector Mid Bowling Boots keep you stable and expertly supported when you menacingly thunder in and… https://t.co/dwen4gv0Pb
#
#
# Puma EvoSpeed cricket bats has extreme hitting power and the ability to make a real impact at the crease.
# #Puma… https://t.co/u7oxpIhtVk
#
#
# Save 40% on the Kookaburra Pro Tour Cricket Wheelie Bag, it has a vented external pad pockets (2 pads), internal pa… https://t.co/qBeqrlPaZv
#
#
# The Adidas Adipower SL22 Cricket Shoe is perfect for batters, with comfort and speed at its very core – turn those… https://t.co/2D3heHPY9n
#
#
# Create an impact with the Mythos range. Concave back profile and an extended sweet spot for those sweetly timed sho… https://t.co/9mFheMH3me
#
#
# Gray Nicolls Shockwave 2000 batting gloves has an improved protection and comfortable feel, offering greater flexib… https://t.co/mIA6joScx5
#
#
# Adidas Adipower Vector Cricket Shoes are a flatter, more traditional cricket spike for bowlers and all-rounders.… https://t.co/ckelzz1q9n
#
#
# Kookaburra Pro D3000 duffle cricket bag has 2 external bat sleeves with padded straps and a cushioned back panel.… https://t.co/oiRbdV4Aei
#
#
# Gunn &amp; Moore Original LE batting pads has XRD extreme impact protection. The difference in XRD protection is especi… https://t.co/4ehvDlvttk
#
#
# Gray Nicolls Powerbow 6X has a powerful blade with a beguiling light pick-up.
# Armed with an unfailingly ability to… https://t.co/ZnY72RuYVi
#
#
# The new Kookaburra Glare cricket bat range has a traditional profile, combined with thick edges to display power an… https://t.co/EI4JtJhd39
#
#
# Gunn &amp; Moore Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened bla… https://t.co/g4deDhfCjM
#
#
# The Masuri Vision series cricket helmets, as worn by many players on the international arena, are built for a high… https://t.co/E1gkQ54OKj
#
#
# Take Charge this season with the new addition of the Kookaburra Charge range. Built to provide the ultimate pick up… https://t.co/EE41BaCN12
#
#
# Gunn &amp; Moore Haze cricket bat has a lightweight design and pick up. It has a mid to high sweetspot for controlled p… https://t.co/zZm4nZczdj
#
#
# With distinctive graphics and a extended sweet spot the Kookaburra Nickle has the perfect combination to make sure… https://t.co/RLp5x9rfN4
#
#
# The Gray Nicolls classic bats offer a unique traditional profile for those who enjoy playing classically timed shot… https://t.co/6g7mjzoNZD
#
#
# Save up to 40% on Gunn &amp; Moore 808 batting pads, the PU Pad with mesh instep for superb all day comfort and the GM… https://t.co/esNzGuLOlp
#
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/dLHlcQnfKI
#
#
# When only the very best cricket bat will do, look no further than the Gray-Nicolls Legend. The pinnacle of the game… https://t.co/vbGtg8Lt96
#
#
# Save 40% on the Kookaburra Pro Tour Cricket Wheelie Bag, it has a vented external pad pockets (2 pads), internal pa… https://t.co/zhGr5nL2ao
#
#
# Gunn &amp; Moore Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened bla… https://t.co/wHJWRL1XdS
#
#
# Gray Nicolls Supernova has evolved with the game. As cricket develops batsmen will need to learn to adapt and the S… https://t.co/J1szyiHLjF
#
#
# Kookaburra Kahuna 2.0 batting gloves offer comfort, protection and contemporary style, offering all-round playabili… https://t.co/N6ZBp4mfHG
#
#
# Gunn and Moore cricket bats 2019 are made at their industry-leading Nottingham-based factory and utilise specialist… https://t.co/QJX1A4fJ7F
#
#
# After the tremendous success of the new Scoop XVII last year, Gray-Nicolls welcomes back another legendary bat to t… https://t.co/q5sjLOLf32
#
#
# Gunn &amp; Moore Original Duffle Cricket Bag is a spacious, well-constructed cricket bag suiting a variety of playing l… https://t.co/EnRJE3Z7U1
#
#
# The new Kookaburra range are online now, the bat have a range of new profiles with some new designs.
# #Kookaburra… https://t.co/BbDvlMAcnc
#
#
# Deliver your best performance with the new Diamond range from Gunn and Moore. Designed to have a power arc bow, fee… https://t.co/WKwv0FOdeX
#
#
# Gray-Nicolls Legend batting pads features light high density foam bolsters reinforced with cane rods and a vapour f… https://t.co/P7SwAI8QLs
#
#
# Save 40% on the Kookaburra Pro Tour Cricket Wheelie Bag, it has a vented external pad pockets (2 pads), internal pa… https://t.co/kmcGXbn9DQ
#
#
# Gunn &amp; Moore have released their new range of cricket bats for 2019, the bat are are made at their industry-leading… https://t.co/pVY8FoRzoV
#
#
# The Gray Nicolls Shockwave batting gloves are a striking range, with improved protection and comfortable feel, offe… https://t.co/94rVUdnPr7
#
#
# The Kookaburra Ghost Cricket Bat is an absolute monster! A giant profile with minimal scalloping means even the lon… https://t.co/R7JDm5s0N9
#
#
# Gunn &amp; Moore Diamond 808 Batting Gloves has PU protection on the back of the hand and HD Foam in the finger rolls.… https://t.co/LN2glyW4kl
#
#
# Save up to 40% on Gunn &amp; Moore Original Duffle Cricket Bag.
# #GM2018 #Duffle #Original
# https://t.co/lH7ufrk4oR https://t.co/IHeCvaXRYe
#
#
# IIntroducing Gunn &amp; Moore Zelos cricket bat for 2018/19, the Zelos bat is perfect for any situation. The bat itself… https://t.co/Z9lYaSRpe3
#
#
# The iconic Kahuna has been the spearhead of the Kookaburra range for the past 14 years. It has a powerful profile,… https://t.co/CTpH736elL
#
#
# Gray Nicolls Supernova has evolved with the game. As cricket develops batsmen will need to learn to adapt and the S… https://t.co/36Cal6WPht
#
#
# Introducing Gunn &amp; Moore Mythos cricket bat for 2018/19, the Mythos bat is endorsed by Rory Burns. The bat itself h… https://t.co/OsqpbDHUsG
#
#
# There will be no shortage of boundaries with the new Kookaburra Rampage. Just as the name suggests runs will be pro… https://t.co/sAiXoKkr79
#
#
# With a pronounced high-middle, full profile and intimidating edges, the Gray Nicolls Shockwave is a bat that will a… https://t.co/j4ac6PKPzU
#
#
# Introducing Gunn &amp; Moore Noir cricket bat for 2018/19, the Noir bat is endorsed by Oli Pope. The bat itself has a l… https://t.co/u3o5esp4iq
#
#
# Kookaburra Nickel cricket bats are new for 2018/19. With its flashy grey and yellow graphics the bat is sure to be… https://t.co/jeEvf2zG5b
#
#
# The Gray Nicolls Powerbow 6X continues the long tradition of the Powerbow range, a bat that classical stroke makers… https://t.co/57GEHT4oOF
#
#
# The Kookaburra Surge 800 provides a distinctive profile where the enhance toe allows for greater pick up. The styli… https://t.co/LpCF8AcP82
#
#
# Introducing Gunn &amp; Moore Diamond cricket bat for 2018/19, the Diamond bat is endorsed by Ben Stokes.  The bat itsel… https://t.co/xtNKcYVERa
#
#
# Gunn &amp; Moore Original L E Batting Gloves absorbs up to 90% of energy when impacted at high strain rates. Soft and c… https://t.co/wpzVVrGbYv
#
#
# Save up to 40% on the New Balance TC 560 Wheelie Bag, it has a 3 wheel intergrated system that is suitable for on a… https://t.co/mzhfMVRupK
#
#
# Gray Nicolls Kronus batting gloves are a beautifully designed range which gives any player the Golden touch! With i… https://t.co/uEOYWhhfPL
#
#
# Save up to 40% on Gunn &amp; Moore 808 batting pads, the PU Pad with mesh instep for superb all day comfort and the GM… https://t.co/PXWqJSdgvA
#
#
# Save upto 40% on Gunn &amp; Moore Purist Geo II Cricket Helmet, the helmet is technically advanced with a contemporary… https://t.co/sTslr1uRC6
#
#
# Save up to 40% on New Balance DC 680 Wheelie Cricket Bag. The bag is designed for cricketers always on the move.… https://t.co/LgXA2YaPsF
#
#
# The Gunn and Moore Zelos DXM cricket bats have a low to mid sweet spot on this blade which makes it perfect for bat… https://t.co/lXSLhwYGXs
#
#
# The iconic Kahuna range has been around for over a decade as a staple piece of Kookaburra’s collection. Uniquely cr… https://t.co/nJNOuQMKN8
#
#
# Gray-Nicolls Velocity XP1 1000 Cricket Bag is a large but practical bag designed for the modern day cricketer – lar… https://t.co/c9pniBPBoP
#
#
# Save up to 40% on Gunn &amp; Moore Original batting pads. These gloves has XRD Extreme Impact Protection which makes th… https://t.co/OrP1EzGb6P
#
#
# Gray Nicolls Classic Collection has been created for batsmen who are serious about their game. These beautiful bats… https://t.co/W5obmO6UFC
#
#
# Save up to 37% on the Kookaburra Pro tour wheelie bag.  The bag has vented external pad pockets (2 pads), internal… https://t.co/hQc5PcepEH
#
#
# The Kookaburra Ghost Cricket Bat is an absolute monster! A giant profile with minimal scalloping means even the lon… https://t.co/kN3bOW4dBu
#
#
# Save up to 40% on Gunn &amp; Moore Original Duffle Cricket Bag.
# #GM2018 #Duffle #Original
# https://t.co/WFnUDdnKwJ https://t.co/Drt8k9PAf8
#
#
# Teams have been announced!
# #EngvSL #Dambulla #ODI https://t.co/WaYIfMltKp
#
#
# The Battle of the Lions start today @ 10:00am BST, Who do you think will come out on top today and in the series?… https://t.co/H3onZEG65K
#
#
# With its unique design and smart storage pockets, the Gray Nicolls Kronus 400 Duffle Bag is versatille, manouverabl… https://t.co/5xXrBryeUp
#
#
# The GM Chrome L555 bats have a traditional blade with massive contoured edges and a partially concaved back profile… https://t.co/zeY7flEX29
#
#
# The vibrant graphics makes the Kookaburra Fever range all about the big shots. An explosive profile design makes it… https://t.co/kxvsI9XSDV
#
#
# Kookaburra KCS 1500 Rubber cricket shoes has Kookaburra ‘cage’ technology offering essential mid-foot stability and… https://t.co/6kRrx5v9Pc
#
#
# The Gray Nicolls  Kronus provides a deceptive profile. A carefully crafted bat which provides a powerful blade but… https://t.co/rZKa0LMo7t
#
#
# Aero P2 strippers deliver the key performance elements of better comfort, protection, speed, and durability for all… https://t.co/VedgTfxIVN
#
#
# Gray-Nicolls Legend batting gloves has a multi-sectioned interlocking "V" design maximises flexibility and movement… https://t.co/xT8alnUVL6
#
#
# The Surge provides a distinctive profile where the enhance toe allows for greater pick up. The stylish graphics has… https://t.co/HDIgloIIfi
#
#
# The EvoSpeed bat collection sets a new benchmark to deliver high performance hitting power with a re-weighted balan… https://t.co/TOEJCg0GVj
#
#
# Shrey helmets offer increased protection for the face, sides and the back of head, ensuring that ultimate protectio… https://t.co/9xzwIWKCs7
#
#
# The Kookaburra Blaze presents a pro preferred full profile, allowing you to play shots all around the ground. With… https://t.co/NQR4GYUbQy
#
#
# RT @ECB_cricket: Andrew Strauss steps down as Director of England Cricket
# https://t.co/Jm82lIKXbe https://t.co/3VPmozgb53
#
#
# The Masuri Vision series cricket helmets, as worn by many players on the international arena, are built for a high… https://t.co/lOJV71xEti
#
#
# Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of playing levels,… https://t.co/LZmUtBWuKV
#
#
# The exclusive range from West Indian Cricketer Carlos Brathwaite. Bringing you the first series from his collection… https://t.co/Rk6xUlf7km
#
#
# The DC gloves will be the perfect fit for the new aged cricketer wanting to play dynamic shots, Fully flexible and… https://t.co/dIRLDaRNpR
#
#
# Gray-Nicolls Test Opener cricket helmet has refinements to the moulded peak and concentric steel bracing on the Ape… https://t.co/zwklxgKtTx
#
#
# Whether you’re at the crease or running up to bowl, the GEL-100 NOT OUT will keep your feet comfortable so you can… https://t.co/bZsaseAQgA
#
#
# Gunn &amp; Moore Icon Geo cricket helmet is traditionally styled and technically advance which makes it the ideal helme… https://t.co/gBWJBC5rVo
#
#
# Adidas XT white currently used by Stuart Broad and Liam Livingstone not only provides clean graphics but also ensur… https://t.co/suP2dLemqZ
#
#
# Gunn and Moore 909 Wheelie cricket bag is ideal for any young cricketer, this cricket bag provides lots of space fo… https://t.co/p5kyGzdiF3
#
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/7odJYLdi3N
#
#
# Gray-Nicolls Custom Made Cricket Bats exclusively from Cricket Direct – an ultimate performance cricket bat tailore… https://t.co/N7denvfUTu
#
#
# Kookaburra KCS 1500 rubber cricket shoes has a lightweight insole with heel and front shock absorption, the low pro… https://t.co/cNEn7j7ihS
#
#
# Kookaburra Pro 1200 Cricket Helmet has a ergonomically designed shape for superb comfort, fit and visibility. Light… https://t.co/ZQ0d5Mvaxj
#
#
# The Adidas XT Black range is all about high performance and superior style. Carefully crafted to provide the ultima… https://t.co/ikNa77XwaP
#
#
# In your hunt for runs, the Gray Nicolls Predator 3 range offers players ultimate protection and comfort, with impro… https://t.co/Wc8XpybGFx
#
#
# Kookaburra Pro D6 Cricket Duffle Bag has medium storage capacity with padded shoulder straps.
# #TeamKookaburra… https://t.co/D0PYbbZ6Va
#
#
# Rise to the occasion with the New Balance TC range. Developed with the serious cricketer in mind. The TC range is a… https://t.co/CJNeNmgZm7
#
#
# Uniquely crafted, Kookaburra carefully designed to provide a powerful profile. Each year the Kahuna range is analys… https://t.co/9MCPCEBpDv
#
#
# Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of playing levels,… https://t.co/D2yNFCqCgh
#
#
# Powerbow a classic range from Gray Nicolls has an enhanced bow and low blade profile, these bats are ideal for thos… https://t.co/JoiSNsYl1J
#
#
# GM Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened blade with a… https://t.co/syWWwuEOB3
#
#
# The Puma EvoPower range optimises and aids perfomance with comfortable, technically superior products.
# #EvoPower… https://t.co/vjzh5k7Fi7
#
#
# The batsman can move in a more natural way, the Strippers just snug fit to become part of you. This translates to f… https://t.co/103EiQFkAk
#
#
# Spartan's Jonny Bairstow cricket bat range is here! The range is for the powerful and dominating stroke maker whils… https://t.co/oYa3MkLq78
#
#
# The DC batting gloves will be the perfect fit for the new aged cricketer wanting to play dynamic shots.
# #NBcricket… https://t.co/NM0gjRbq59
#
#
# Engineered for greater comfort and lighter weight without any compromise on protection. Shrey helmets offer increas… https://t.co/oqqPwiMGG0
#
#
# The EvoSpeed bat collection sets a new benchmark to deliver high performance hitting power with a re-weighted balan… https://t.co/m1b7g1rdJ3
#
#
# The Masuri Vision series cricket helmets, as worn by many players on the international arena, are built for a high… https://t.co/jQLQAwq3PJ
#
#
# The velocity XP1 range offers protection which has been designed using foam material designed to reduce the weight… https://t.co/EinsGFcbLE
#
#
# Slazenger V800 cricket bats are perfect for those stroke players who strive for precision and control in every shot… https://t.co/aW2Ni1chTk
#
#
# New Balance DC 2018 cricket bats are designed specifically for those who play shots all around the ground. This ran… https://t.co/gYmCKAnAO4
#
#
# Salix AJK cricket bats are skilfully crafted to give thick edges and large driving area to give maximum power to ea… https://t.co/NRJph5IZgp
#
#
# Kookaburra Pro Tour Cricket Wheelie Bag has a vented external pad pockets (2 pads), internal padded bat pocket (2 b… https://t.co/fAPIv06vLd
#
#
# The Zelos range inspired by England’s Ben Stokes.  Just like the man himself, the bats possess a powerful frame, id… https://t.co/qRyNkMAYGy
#
#
# Gray Nicolls Kronus is the blade for any batsman looking to dominate the opposition. Deceptive, beautiful and craft… https://t.co/YT2kSV5ZOb
#
#
# Kookaburra Pro Players Wheelie Cricket Bag has a vertical storage facility with semi rigid skeleton. Tapered design… https://t.co/rbC29UeZw5
#
#
# The Classic Collection has been created for batsmen who are serious about their game. This beautiful range of bats… https://t.co/nGrekuiFt9
#
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/ipfayQBll2
#
#
# Gunn &amp; Moore 909 batting pads has XRD Extreme Impact Protection. The XRD protection difference is especially appare… https://t.co/iCgRyU4gfq
#
#
# Kookaburra Pro Xtreme Cricket Duffle Bag has vented external pad pockets (2 pads), internal padded bat pocket (2 ba… https://t.co/dgKN89ErXq
#
#
# A lightweight, entry level pad, the Ultimate has a hardwearing Nylon instep and Top Hat to offer players a durable… https://t.co/ggewJoN0iE
#
#
# The Salix Pod Cricket Bat is an absolute beast – your hits stay hit and opposing bowlers will be running scared.… https://t.co/Fk741tQumj
#
#
# Gunn &amp; Moore 606 Batting Gloves has a new multi-section back of hand design for increased flexibility and comfort.… https://t.co/tliu1DhDL3
#
#
# With its unique design and smart storage pockets, the Kronus 400 Duffle Bag is versatille, manouverable and fuction… https://t.co/InJArYQoOW
#
#
# What a way to end your test career! Alastair Cook take a bow. It has been a pleasure watching over the last decade,… https://t.co/xdTJolYZZt
#
#
# GM Mana L540 bats have a shortened blade with a pronounced spine profile, substantial edges and a flatter toe to gi… https://t.co/7QTNYdWstC
#
#
# It’s powerful profile, big edges and world renowned graphics make no apologies, ideal for the stroke maker who like… https://t.co/5sghlEZqZb
#
#
# New Balance TC batting gloves, tradition meets technology. The TC gloves are breathable and perfectly postioned spl… https://t.co/2HtfAXPWSA
#
#
# Gray-Nicolls Custom Made Cricket Bats exclusively from Cricket Direct – an ultimate performance cricket bat tailore… https://t.co/LBuRksFx3H
#
#
# Whether you’re at the crease or running up to bowl, Asics Gel 100 Not Out cricket shoes will keep your feet comfort… https://t.co/PAXcwR9Xgb
#
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/a98nxi5ixy
#
#
# Asics Gel Advance 6 cricket shoes is a lightweight shoe that combines great cushioning and flexibility for the cric… https://t.co/Mo2SEoDXOK
#
#
# Limited time offer ending 10/09/18 - Save up to 25% on Puma Virat Kohli EvoSpeed 18.1 Cricket Shoes. USE CODE : SAV… https://t.co/jHPeR32I1v
#
#
# Limited time offer ending 10/09/18 - Save up to 45% on Kookaburra Ghost 2000 cricket bat.  #TeamKookaburra… https://t.co/QnrdsuOeRX
#
#
# Gray-Nicolls Legend Cricket Duffle Bag is the ultimate in style and performance duffle bags – a true Gray Nicolls c… https://t.co/xJCnCWAbxi
#
#
# Slazenger V100 cricket bats designed for the all-rounder, the V100 range offers an ultra-light weight bat with supr… https://t.co/ItuLG0ngUg
#
#
# The GM Chrome L555 bats have a traditional blade with massive contoured edges and a partially concaved back profile… https://t.co/xOixhsoK02
#
#
# Kookaburra Fever cricket bats has an explosive profile design makes it ideal for the destructive player. The perfec… https://t.co/zGimF69IWV
#
#
# Gunn &amp; Moore 707 Duffle Cricket Bag is ideal for cricketer of all levels. It has a 2 bat pockets and has 2 padded a… https://t.co/UFwbvQttiS
#
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/rQK0d6xQiU
#
#
# Gunn &amp; Moore 909 batting pads has XRD Extreme Impact Protection. The XRD protection difference is especially appare… https://t.co/5opNRSGPZr
#
#
# An ergonomically designed duffle bag, the Gray Nicolls Kronus 800 pairs smart storage with premium style to be an u… https://t.co/8FZuRCivRv
#
#
# Gunn &amp; Moore Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened bla… https://t.co/PNokcVsoIl
#
#
# The iconic Kahuna range has been around for over a decade as a staple piece of Kookaburra’s collection. Uniquely cr… https://t.co/csHXAfcLsG
#
#
# Proud to introduce the exclusive range from West Indian Cricketer Carlos Brathwaite. Bringing you the first series… https://t.co/Sd8qc8lCav
#
#
# A Gray-Nicolls custom made cricket bat is our way of guaranteeing you get the highest quality cricket bat that trul… https://t.co/zjiAX2L6vz
#
#
# Kookaburra KCS 1500 rubber cricket shoes has a lightweight insole with heel and front shock absorption, the low pro… https://t.co/lxgWp0q8JI
#
#
# Gunn and Moore 909 Wheelie cricket bag is ideal for any young cricketer, this cricket bag provides lots of space fo… https://t.co/u2gjHI1JgC
#
#
# The Classic Collection has been created for batsmen who are serious about their game. This beautiful range of bats… https://t.co/sVdiAZK137
#
#
# Shrey helmets offer increased protection for the face, sides and the back of head, ensuring that ultimate protectio… https://t.co/uzG7U17Om4
#
#
# Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of playing levels,… https://t.co/nxt8pSk1EB
#
#
# The Kookaburra Ghost Cricket Bat is an absolute monster! A giant profile with minimal scalloping means even the lon… https://t.co/1Q5J3SnLnv
#
#
# The Gray-Nicolls Legend Cricket Bat offers players of all levels the opportunity to create your own history by reap… https://t.co/uEAoq6F3Mu
#
#
# Kookaburra Pro 2750 wheelie bag has a tapered design for greater stability in use as well as multiple pockets with… https://t.co/WBrOxsQoK7
#
#
# New Balance CK4040 cricket shoes are designed working with some of the world’s best bowlers this shoe delivers prot… https://t.co/pYH6LbE5Vs
#
#
# Congratulations to James Vince on being called back to the England Test side. He endorses the Gunn &amp; Moore Haze cri… https://t.co/qO8KYeHrbt
#
#
# Puma EvoSpeed bat collection sets a new benchmark to deliver high performance hitting power with a re-weighted bala… https://t.co/hyKdCwRNx0
#
#
# Gray-Nicolls Powerbow 6 batting gloves are a traditional glove shape with added foam for maximum movement, to offer… https://t.co/oUb6HwSYPD
#
#
# Slazenger V100 cricket bats are designed for the all-rounder, the V100 range offers an ultra-light weight bat with… https://t.co/CnFEJCIYn0
#
#
# Gray-Nicolls Kronus batting pads have an elegant design offering players a batting pad that provide light weight pr… https://t.co/tN4aMMXo2P
#
#
# The Gunn and Moore Zelos DXM cricket bats have a low to mid sweet spot on this blade which makes it perfect for bat… https://t.co/5UEekvWK32
#
#
# Gray Nicolls Kronus is the blade for any batsman looking to dominate the opposition. It holds a hidden destructive… https://t.co/d3cNgxwmRn
#
#
# Mimic the stars with a pair of Kookaburra Batting Gloves. Think pro-quality batting gloves. Think Kookaburra.… https://t.co/gRLvS0F7KH
#
#
# Gray Nicolls Atomic cricket helmet has a redesigned grille and peak offer greater resistance to frontal ball strike… https://t.co/X3St9m4R9y
#
#
# Oakley Radar® eyewear combined everything we learned from decades of research with the world’s best athletes, and w… https://t.co/xKsnTNjbjM
#
#
# The batsman can move in a more natural way, the Strippers just snug fit to become part of you. This translates to f… https://t.co/6AebsURdI2
#
#
# The Gunn &amp; Moore Haze cricket bat has a mid to high swell position for power play, allowing you to punish anything… https://t.co/WCr2sDkedt
#
#
# A Gray-Nicolls custom made cricket bat is your way of guaranteeing you get the highest quality cricket bat that tru… https://t.co/OsrkwsYcng
#
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/M6BgUwEJuQ
#
#
# Whether you’re at the crease or running up to bowl, Asics Gel 100 Not Out cricket shoes will keep your feet comfort… https://t.co/fBf6wl6JzV
#
#
# New Balance TC batting gloves, tradition meets technology. The TC gloves are breathable and perfectly postioned spl… https://t.co/LxfBkBrqGL
#
#
# The Gray-Nicolls Legend Cricket Bat offers players of all levels the opportunity to create your own history by reap… https://t.co/P9Wao02e5X
#
#
# Asics Gel Advance 6 cricket shoes is a lightweight shoe that combines great cushioning and flexibility for the cric… https://t.co/QAkBKyz5Ef
#
#
# Gunn &amp; Moore Original Limited Edition batting gloves absorbs up to 90% of energy when impacted at high strain rates… https://t.co/qyNG9WXPI7
#
#
# The Surge provides a distinctive profile where the enhance toe allows for greater pick up. The stylish graphics has… https://t.co/yKdmU3YyE5
#
#
# Slazenger V600 Cricket Bats are carefully crafted to provide maximum edges to ensure power is delivered with every… https://t.co/HF0VLIEzqJ
#
#
# Gunn &amp; Moore 909 batting pads have XRD Extreme Impact Protection is flexible, brethable and lightweight.
# #GM2018 #… https://t.co/ZOvACAIGSd
#
#
# One of Gray Nicolls staple ranges, Powerbow 6 with a full blade profile making it an ideal bat for the classic well… https://t.co/HDI7nLdnlD
#
#
# With its unique design and smart storage pockets, the Kronus 400 Duffle Bag is versatille, manouverable and fuction… https://t.co/Xe8CF8nC4O
#
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/xUFbkEcY0A
#
#
# The Gunn and Moore 808 LE Batting Pads. The High Density Foam and Cane construction in this high quality batting pa… https://t.co/bVvH8t6SAY
#
#
# The Salix Raw T20 Cricket Bat has advanced profiling, pressing and shaping.
# #SalixBats #Salix… https://t.co/B5u6CTSHlu
#
#
# It’s powerful profile, big edges and world renowned graphics make no apologies, ideal for the stroke maker who like… https://t.co/9LL6nXi8Xb
#
#
# A medium sized bag , The Powerbow6 600 Bag is a fusion of innovation and fuctionality to optimise space and storage… https://t.co/sgr5fy61WU
#
#
# Gray-Nicolls Prestige batting pads has the leg-hugging design combined with "butterfly' padded straps and buckles o… https://t.co/EaqcAlcEQc
#
#
# Engineered for greater comfort and lighter weight without any compromise on protection. Shrey helmets offer increas… https://t.co/s2o47qg6vz
#
#
# Masuri Vision Series Cricket Helmets are lightweight, comfortable and have great ventilation, providing supreme pro… https://t.co/nzbIjsFawL
#
#
# @englandcricket  has released the squad for the 2nd test match against India @ Lord's. Who do you think will play?… https://t.co/unUlpUzHpu
#
#
# Gunn &amp; Moore 808 Batting Gloves has PU protection on the back of the hand and HD Foam in the finger rolls.
# #GM2018… https://t.co/HsVvhKE5Rx
#
#
# The exclusive range from West Indian Cricketer Carlos Brathwaite. Bringing you the first series from his collection… https://t.co/gdZXgCmp6K

# %%
# Count words
from collections import Counter  # This is just a fancy dict mapping from object->int, starting at 0.
counts = Counter()
for tweet in timeline:
    counts.update(tweet['text'].lower().split())
print('found %d unique terms in %d tweets' % (len(counts), len(timeline)))
counts.most_common(10)
# Out:
# found 1172 unique terms in 200 tweets
# [('the', 211),
#  ('a', 128),
#  ('and', 104),
#  ('cricket', 93),
#  ('with', 73),
#  ('for', 70),
#  ('to', 69),
#  ('has', 57),
#  ('bat', 53),
#  ('is', 52)]

# %%
import re
for tweet in timeline:
    deal = tweet['text']
    print(deal + '\n')
# Out:
# Puma Special Edition Gold is perfectly balanced to produce a combination of unrivaled pick-up and a devastating amo… https://t.co/qDFOYBiZm5
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/pKYAI6W01y
#
# The New Balance 2019 range has a striking combination of colours together with the large features on the bat again… https://t.co/RJ3XoC1WLT
#
# The Kookaburra Ghost Cricket Bat is an absolute monster – a giant profile with minimal sculpting, for players looki… https://t.co/RNQ4LTxMNF
#
# Save 40% on Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of pla… https://t.co/cMfMBYU3Pm
#
# Deliver your best performance with the new diamond range from Gunn and Moore. Designed to have a power arc bow, fee… https://t.co/pHKNJcqJp5
#
# Kookaburra Pro D3000 duffle cricket bag has an external bat sleeve for 2 bats, padded straps with an airflow mesh c… https://t.co/i5FP9iBlxx
#
# Puma Special Edition  is perfectly balanced to produce a combination of unrivaled pick-up and a devastating amount… https://t.co/GdGRDZSzRr
#
# Gray Nicolls Powerbow 6X has a powerful blade with a beguiling light pick-up.
# Armed with an unfailingly ability to… https://t.co/5l84Rd90Wh
#
# Adidas Adizero SL22 Boost is a cricket trainer that is perfect for training or batting on dry surfaces.… https://t.co/kJ5QH5Pmgc
#
# Gray-Nicolls Legend batting gloves has a multi-sectioned interlocking "V" design maximises flexibility and movement… https://t.co/Pc5IsrQR8h
#
# Reveal your dark side with the Gunn &amp; Moore Noir range. New to 2019, the profile is all about delivering menacing p… https://t.co/O7E4IrU7AY
#
# With the Kookaburra Rampage cricket bat there will be no shortage of boundaries with the new range. Just as the nam… https://t.co/ZF93gp6KW1
#
# Puma Special Edition white cricket bat features a powerful hitting zone, superior pick-up and exquisite balance.… https://t.co/APNJrcDEI2
#
# With a pronounced high-middle, full profile and intimidating edges, the Gray Nicolls Shockwave is a bat that will a… https://t.co/r9lBm5B99A
#
# Adidas Adipower Vector Mid Bowling Boots keep you stable and expertly supported when you menacingly thunder in and… https://t.co/dwen4gv0Pb
#
# Puma EvoSpeed cricket bats has extreme hitting power and the ability to make a real impact at the crease.
# #Puma… https://t.co/u7oxpIhtVk
#
# Save 40% on the Kookaburra Pro Tour Cricket Wheelie Bag, it has a vented external pad pockets (2 pads), internal pa… https://t.co/qBeqrlPaZv
#
# The Adidas Adipower SL22 Cricket Shoe is perfect for batters, with comfort and speed at its very core – turn those… https://t.co/2D3heHPY9n
#
# Create an impact with the Mythos range. Concave back profile and an extended sweet spot for those sweetly timed sho… https://t.co/9mFheMH3me
#
# Gray Nicolls Shockwave 2000 batting gloves has an improved protection and comfortable feel, offering greater flexib… https://t.co/mIA6joScx5
#
# Adidas Adipower Vector Cricket Shoes are a flatter, more traditional cricket spike for bowlers and all-rounders.… https://t.co/ckelzz1q9n
#
# Kookaburra Pro D3000 duffle cricket bag has 2 external bat sleeves with padded straps and a cushioned back panel.… https://t.co/oiRbdV4Aei
#
# Gunn &amp; Moore Original LE batting pads has XRD extreme impact protection. The difference in XRD protection is especi… https://t.co/4ehvDlvttk
#
# Gray Nicolls Powerbow 6X has a powerful blade with a beguiling light pick-up.
# Armed with an unfailingly ability to… https://t.co/ZnY72RuYVi
#
# The new Kookaburra Glare cricket bat range has a traditional profile, combined with thick edges to display power an… https://t.co/EI4JtJhd39
#
# Gunn &amp; Moore Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened bla… https://t.co/g4deDhfCjM
#
# The Masuri Vision series cricket helmets, as worn by many players on the international arena, are built for a high… https://t.co/E1gkQ54OKj
#
# Take Charge this season with the new addition of the Kookaburra Charge range. Built to provide the ultimate pick up… https://t.co/EE41BaCN12
#
# Gunn &amp; Moore Haze cricket bat has a lightweight design and pick up. It has a mid to high sweetspot for controlled p… https://t.co/zZm4nZczdj
#
# With distinctive graphics and a extended sweet spot the Kookaburra Nickle has the perfect combination to make sure… https://t.co/RLp5x9rfN4
#
# The Gray Nicolls classic bats offer a unique traditional profile for those who enjoy playing classically timed shot… https://t.co/6g7mjzoNZD
#
# Save up to 40% on Gunn &amp; Moore 808 batting pads, the PU Pad with mesh instep for superb all day comfort and the GM… https://t.co/esNzGuLOlp
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/dLHlcQnfKI
#
# When only the very best cricket bat will do, look no further than the Gray-Nicolls Legend. The pinnacle of the game… https://t.co/vbGtg8Lt96
#
# Save 40% on the Kookaburra Pro Tour Cricket Wheelie Bag, it has a vented external pad pockets (2 pads), internal pa… https://t.co/zhGr5nL2ao
#
# Gunn &amp; Moore Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened bla… https://t.co/wHJWRL1XdS
#
# Gray Nicolls Supernova has evolved with the game. As cricket develops batsmen will need to learn to adapt and the S… https://t.co/J1szyiHLjF
#
# Kookaburra Kahuna 2.0 batting gloves offer comfort, protection and contemporary style, offering all-round playabili… https://t.co/N6ZBp4mfHG
#
# Gunn and Moore cricket bats 2019 are made at their industry-leading Nottingham-based factory and utilise specialist… https://t.co/QJX1A4fJ7F
#
# After the tremendous success of the new Scoop XVII last year, Gray-Nicolls welcomes back another legendary bat to t… https://t.co/q5sjLOLf32
#
# Gunn &amp; Moore Original Duffle Cricket Bag is a spacious, well-constructed cricket bag suiting a variety of playing l… https://t.co/EnRJE3Z7U1
#
# The new Kookaburra range are online now, the bat have a range of new profiles with some new designs.
# #Kookaburra… https://t.co/BbDvlMAcnc
#
# Deliver your best performance with the new Diamond range from Gunn and Moore. Designed to have a power arc bow, fee… https://t.co/WKwv0FOdeX
#
# Gray-Nicolls Legend batting pads features light high density foam bolsters reinforced with cane rods and a vapour f… https://t.co/P7SwAI8QLs
#
# Save 40% on the Kookaburra Pro Tour Cricket Wheelie Bag, it has a vented external pad pockets (2 pads), internal pa… https://t.co/kmcGXbn9DQ
#
# Gunn &amp; Moore have released their new range of cricket bats for 2019, the bat are are made at their industry-leading… https://t.co/pVY8FoRzoV
#
# The Gray Nicolls Shockwave batting gloves are a striking range, with improved protection and comfortable feel, offe… https://t.co/94rVUdnPr7
#
# The Kookaburra Ghost Cricket Bat is an absolute monster! A giant profile with minimal scalloping means even the lon… https://t.co/R7JDm5s0N9
#
# Gunn &amp; Moore Diamond 808 Batting Gloves has PU protection on the back of the hand and HD Foam in the finger rolls.… https://t.co/LN2glyW4kl
#
# Save up to 40% on Gunn &amp; Moore Original Duffle Cricket Bag.
# #GM2018 #Duffle #Original
# https://t.co/lH7ufrk4oR https://t.co/IHeCvaXRYe
#
# IIntroducing Gunn &amp; Moore Zelos cricket bat for 2018/19, the Zelos bat is perfect for any situation. The bat itself… https://t.co/Z9lYaSRpe3
#
# The iconic Kahuna has been the spearhead of the Kookaburra range for the past 14 years. It has a powerful profile,… https://t.co/CTpH736elL
#
# Gray Nicolls Supernova has evolved with the game. As cricket develops batsmen will need to learn to adapt and the S… https://t.co/36Cal6WPht
#
# Introducing Gunn &amp; Moore Mythos cricket bat for 2018/19, the Mythos bat is endorsed by Rory Burns. The bat itself h… https://t.co/OsqpbDHUsG
#
# There will be no shortage of boundaries with the new Kookaburra Rampage. Just as the name suggests runs will be pro… https://t.co/sAiXoKkr79
#
# With a pronounced high-middle, full profile and intimidating edges, the Gray Nicolls Shockwave is a bat that will a… https://t.co/j4ac6PKPzU
#
# Introducing Gunn &amp; Moore Noir cricket bat for 2018/19, the Noir bat is endorsed by Oli Pope. The bat itself has a l… https://t.co/u3o5esp4iq
#
# Kookaburra Nickel cricket bats are new for 2018/19. With its flashy grey and yellow graphics the bat is sure to be… https://t.co/jeEvf2zG5b
#
# The Gray Nicolls Powerbow 6X continues the long tradition of the Powerbow range, a bat that classical stroke makers… https://t.co/57GEHT4oOF
#
# The Kookaburra Surge 800 provides a distinctive profile where the enhance toe allows for greater pick up. The styli… https://t.co/LpCF8AcP82
#
# Introducing Gunn &amp; Moore Diamond cricket bat for 2018/19, the Diamond bat is endorsed by Ben Stokes.  The bat itsel… https://t.co/xtNKcYVERa
#
# Gunn &amp; Moore Original L E Batting Gloves absorbs up to 90% of energy when impacted at high strain rates. Soft and c… https://t.co/wpzVVrGbYv
#
# Save up to 40% on the New Balance TC 560 Wheelie Bag, it has a 3 wheel intergrated system that is suitable for on a… https://t.co/mzhfMVRupK
#
# Gray Nicolls Kronus batting gloves are a beautifully designed range which gives any player the Golden touch! With i… https://t.co/uEOYWhhfPL
#
# Save up to 40% on Gunn &amp; Moore 808 batting pads, the PU Pad with mesh instep for superb all day comfort and the GM… https://t.co/PXWqJSdgvA
#
# Save upto 40% on Gunn &amp; Moore Purist Geo II Cricket Helmet, the helmet is technically advanced with a contemporary… https://t.co/sTslr1uRC6
#
# Save up to 40% on New Balance DC 680 Wheelie Cricket Bag. The bag is designed for cricketers always on the move.… https://t.co/LgXA2YaPsF
#
# The Gunn and Moore Zelos DXM cricket bats have a low to mid sweet spot on this blade which makes it perfect for bat… https://t.co/lXSLhwYGXs
#
# The iconic Kahuna range has been around for over a decade as a staple piece of Kookaburra’s collection. Uniquely cr… https://t.co/nJNOuQMKN8
#
# Gray-Nicolls Velocity XP1 1000 Cricket Bag is a large but practical bag designed for the modern day cricketer – lar… https://t.co/c9pniBPBoP
#
# Save up to 40% on Gunn &amp; Moore Original batting pads. These gloves has XRD Extreme Impact Protection which makes th… https://t.co/OrP1EzGb6P
#
# Gray Nicolls Classic Collection has been created for batsmen who are serious about their game. These beautiful bats… https://t.co/W5obmO6UFC
#
# Save up to 37% on the Kookaburra Pro tour wheelie bag.  The bag has vented external pad pockets (2 pads), internal… https://t.co/hQc5PcepEH
#
# The Kookaburra Ghost Cricket Bat is an absolute monster! A giant profile with minimal scalloping means even the lon… https://t.co/kN3bOW4dBu
#
# Save up to 40% on Gunn &amp; Moore Original Duffle Cricket Bag.
# #GM2018 #Duffle #Original
# https://t.co/WFnUDdnKwJ https://t.co/Drt8k9PAf8
#
# Teams have been announced!
# #EngvSL #Dambulla #ODI https://t.co/WaYIfMltKp
#
# The Battle of the Lions start today @ 10:00am BST, Who do you think will come out on top today and in the series?… https://t.co/H3onZEG65K
#
# With its unique design and smart storage pockets, the Gray Nicolls Kronus 400 Duffle Bag is versatille, manouverabl… https://t.co/5xXrBryeUp
#
# The GM Chrome L555 bats have a traditional blade with massive contoured edges and a partially concaved back profile… https://t.co/zeY7flEX29
#
# The vibrant graphics makes the Kookaburra Fever range all about the big shots. An explosive profile design makes it… https://t.co/kxvsI9XSDV
#
# Kookaburra KCS 1500 Rubber cricket shoes has Kookaburra ‘cage’ technology offering essential mid-foot stability and… https://t.co/6kRrx5v9Pc
#
# The Gray Nicolls  Kronus provides a deceptive profile. A carefully crafted bat which provides a powerful blade but… https://t.co/rZKa0LMo7t
#
# Aero P2 strippers deliver the key performance elements of better comfort, protection, speed, and durability for all… https://t.co/VedgTfxIVN
#
# Gray-Nicolls Legend batting gloves has a multi-sectioned interlocking "V" design maximises flexibility and movement… https://t.co/xT8alnUVL6
#
# The Surge provides a distinctive profile where the enhance toe allows for greater pick up. The stylish graphics has… https://t.co/HDIgloIIfi
#
# The EvoSpeed bat collection sets a new benchmark to deliver high performance hitting power with a re-weighted balan… https://t.co/TOEJCg0GVj
#
# Shrey helmets offer increased protection for the face, sides and the back of head, ensuring that ultimate protectio… https://t.co/9xzwIWKCs7
#
# The Kookaburra Blaze presents a pro preferred full profile, allowing you to play shots all around the ground. With… https://t.co/NQR4GYUbQy
#
# RT @ECB_cricket: Andrew Strauss steps down as Director of England Cricket
# https://t.co/Jm82lIKXbe https://t.co/3VPmozgb53
#
# The Masuri Vision series cricket helmets, as worn by many players on the international arena, are built for a high… https://t.co/lOJV71xEti
#
# Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of playing levels,… https://t.co/LZmUtBWuKV
#
# The exclusive range from West Indian Cricketer Carlos Brathwaite. Bringing you the first series from his collection… https://t.co/Rk6xUlf7km
#
# The DC gloves will be the perfect fit for the new aged cricketer wanting to play dynamic shots, Fully flexible and… https://t.co/dIRLDaRNpR
#
# Gray-Nicolls Test Opener cricket helmet has refinements to the moulded peak and concentric steel bracing on the Ape… https://t.co/zwklxgKtTx
#
# Whether you’re at the crease or running up to bowl, the GEL-100 NOT OUT will keep your feet comfortable so you can… https://t.co/bZsaseAQgA
#
# Gunn &amp; Moore Icon Geo cricket helmet is traditionally styled and technically advance which makes it the ideal helme… https://t.co/gBWJBC5rVo
#
# Adidas XT white currently used by Stuart Broad and Liam Livingstone not only provides clean graphics but also ensur… https://t.co/suP2dLemqZ
#
# Gunn and Moore 909 Wheelie cricket bag is ideal for any young cricketer, this cricket bag provides lots of space fo… https://t.co/p5kyGzdiF3
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/7odJYLdi3N
#
# Gray-Nicolls Custom Made Cricket Bats exclusively from Cricket Direct – an ultimate performance cricket bat tailore… https://t.co/N7denvfUTu
#
# Kookaburra KCS 1500 rubber cricket shoes has a lightweight insole with heel and front shock absorption, the low pro… https://t.co/cNEn7j7ihS
#
# Kookaburra Pro 1200 Cricket Helmet has a ergonomically designed shape for superb comfort, fit and visibility. Light… https://t.co/ZQ0d5Mvaxj
#
# The Adidas XT Black range is all about high performance and superior style. Carefully crafted to provide the ultima… https://t.co/ikNa77XwaP
#
# In your hunt for runs, the Gray Nicolls Predator 3 range offers players ultimate protection and comfort, with impro… https://t.co/Wc8XpybGFx
#
# Kookaburra Pro D6 Cricket Duffle Bag has medium storage capacity with padded shoulder straps.
# #TeamKookaburra… https://t.co/D0PYbbZ6Va
#
# Rise to the occasion with the New Balance TC range. Developed with the serious cricketer in mind. The TC range is a… https://t.co/CJNeNmgZm7
#
# Uniquely crafted, Kookaburra carefully designed to provide a powerful profile. Each year the Kahuna range is analys… https://t.co/9MCPCEBpDv
#
# Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of playing levels,… https://t.co/D2yNFCqCgh
#
# Powerbow a classic range from Gray Nicolls has an enhanced bow and low blade profile, these bats are ideal for thos… https://t.co/JoiSNsYl1J
#
# GM Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened blade with a… https://t.co/syWWwuEOB3
#
# The Puma EvoPower range optimises and aids perfomance with comfortable, technically superior products.
# #EvoPower… https://t.co/vjzh5k7Fi7
#
# The batsman can move in a more natural way, the Strippers just snug fit to become part of you. This translates to f… https://t.co/103EiQFkAk
#
# Spartan's Jonny Bairstow cricket bat range is here! The range is for the powerful and dominating stroke maker whils… https://t.co/oYa3MkLq78
#
# The DC batting gloves will be the perfect fit for the new aged cricketer wanting to play dynamic shots.
# #NBcricket… https://t.co/NM0gjRbq59
#
# Engineered for greater comfort and lighter weight without any compromise on protection. Shrey helmets offer increas… https://t.co/oqqPwiMGG0
#
# The EvoSpeed bat collection sets a new benchmark to deliver high performance hitting power with a re-weighted balan… https://t.co/m1b7g1rdJ3
#
# The Masuri Vision series cricket helmets, as worn by many players on the international arena, are built for a high… https://t.co/jQLQAwq3PJ
#
# The velocity XP1 range offers protection which has been designed using foam material designed to reduce the weight… https://t.co/EinsGFcbLE
#
# Slazenger V800 cricket bats are perfect for those stroke players who strive for precision and control in every shot… https://t.co/aW2Ni1chTk
#
# New Balance DC 2018 cricket bats are designed specifically for those who play shots all around the ground. This ran… https://t.co/gYmCKAnAO4
#
# Salix AJK cricket bats are skilfully crafted to give thick edges and large driving area to give maximum power to ea… https://t.co/NRJph5IZgp
#
# Kookaburra Pro Tour Cricket Wheelie Bag has a vented external pad pockets (2 pads), internal padded bat pocket (2 b… https://t.co/fAPIv06vLd
#
# The Zelos range inspired by England’s Ben Stokes.  Just like the man himself, the bats possess a powerful frame, id… https://t.co/qRyNkMAYGy
#
# Gray Nicolls Kronus is the blade for any batsman looking to dominate the opposition. Deceptive, beautiful and craft… https://t.co/YT2kSV5ZOb
#
# Kookaburra Pro Players Wheelie Cricket Bag has a vertical storage facility with semi rigid skeleton. Tapered design… https://t.co/rbC29UeZw5
#
# The Classic Collection has been created for batsmen who are serious about their game. This beautiful range of bats… https://t.co/nGrekuiFt9
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/ipfayQBll2
#
# Gunn &amp; Moore 909 batting pads has XRD Extreme Impact Protection. The XRD protection difference is especially appare… https://t.co/iCgRyU4gfq
#
# Kookaburra Pro Xtreme Cricket Duffle Bag has vented external pad pockets (2 pads), internal padded bat pocket (2 ba… https://t.co/dgKN89ErXq
#
# A lightweight, entry level pad, the Ultimate has a hardwearing Nylon instep and Top Hat to offer players a durable… https://t.co/ggewJoN0iE
#
# The Salix Pod Cricket Bat is an absolute beast – your hits stay hit and opposing bowlers will be running scared.… https://t.co/Fk741tQumj
#
# Gunn &amp; Moore 606 Batting Gloves has a new multi-section back of hand design for increased flexibility and comfort.… https://t.co/tliu1DhDL3
#
# With its unique design and smart storage pockets, the Kronus 400 Duffle Bag is versatille, manouverable and fuction… https://t.co/InJArYQoOW
#
# What a way to end your test career! Alastair Cook take a bow. It has been a pleasure watching over the last decade,… https://t.co/xdTJolYZZt
#
# GM Mana L540 bats have a shortened blade with a pronounced spine profile, substantial edges and a flatter toe to gi… https://t.co/7QTNYdWstC
#
# It’s powerful profile, big edges and world renowned graphics make no apologies, ideal for the stroke maker who like… https://t.co/5sghlEZqZb
#
# New Balance TC batting gloves, tradition meets technology. The TC gloves are breathable and perfectly postioned spl… https://t.co/2HtfAXPWSA
#
# Gray-Nicolls Custom Made Cricket Bats exclusively from Cricket Direct – an ultimate performance cricket bat tailore… https://t.co/LBuRksFx3H
#
# Whether you’re at the crease or running up to bowl, Asics Gel 100 Not Out cricket shoes will keep your feet comfort… https://t.co/PAXcwR9Xgb
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/a98nxi5ixy
#
# Asics Gel Advance 6 cricket shoes is a lightweight shoe that combines great cushioning and flexibility for the cric… https://t.co/Mo2SEoDXOK
#
# Limited time offer ending 10/09/18 - Save up to 25% on Puma Virat Kohli EvoSpeed 18.1 Cricket Shoes. USE CODE : SAV… https://t.co/jHPeR32I1v
#
# Limited time offer ending 10/09/18 - Save up to 45% on Kookaburra Ghost 2000 cricket bat.  #TeamKookaburra… https://t.co/QnrdsuOeRX
#
# Gray-Nicolls Legend Cricket Duffle Bag is the ultimate in style and performance duffle bags – a true Gray Nicolls c… https://t.co/xJCnCWAbxi
#
# Slazenger V100 cricket bats designed for the all-rounder, the V100 range offers an ultra-light weight bat with supr… https://t.co/ItuLG0ngUg
#
# The GM Chrome L555 bats have a traditional blade with massive contoured edges and a partially concaved back profile… https://t.co/xOixhsoK02
#
# Kookaburra Fever cricket bats has an explosive profile design makes it ideal for the destructive player. The perfec… https://t.co/zGimF69IWV
#
# Gunn &amp; Moore 707 Duffle Cricket Bag is ideal for cricketer of all levels. It has a 2 bat pockets and has 2 padded a… https://t.co/UFwbvQttiS
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/rQK0d6xQiU
#
# Gunn &amp; Moore 909 batting pads has XRD Extreme Impact Protection. The XRD protection difference is especially appare… https://t.co/5opNRSGPZr
#
# An ergonomically designed duffle bag, the Gray Nicolls Kronus 800 pairs smart storage with premium style to be an u… https://t.co/8FZuRCivRv
#
# Gunn &amp; Moore Neon L540 bats have massive edges with a reduced sweeping spine for superb pick up and a shortened bla… https://t.co/PNokcVsoIl
#
# The iconic Kahuna range has been around for over a decade as a staple piece of Kookaburra’s collection. Uniquely cr… https://t.co/csHXAfcLsG
#
# Proud to introduce the exclusive range from West Indian Cricketer Carlos Brathwaite. Bringing you the first series… https://t.co/Sd8qc8lCav
#
# A Gray-Nicolls custom made cricket bat is our way of guaranteeing you get the highest quality cricket bat that trul… https://t.co/zjiAX2L6vz
#
# Kookaburra KCS 1500 rubber cricket shoes has a lightweight insole with heel and front shock absorption, the low pro… https://t.co/lxgWp0q8JI
#
# Gunn and Moore 909 Wheelie cricket bag is ideal for any young cricketer, this cricket bag provides lots of space fo… https://t.co/u2gjHI1JgC
#
# The Classic Collection has been created for batsmen who are serious about their game. This beautiful range of bats… https://t.co/sVdiAZK137
#
# Shrey helmets offer increased protection for the face, sides and the back of head, ensuring that ultimate protectio… https://t.co/uzG7U17Om4
#
# Gunn and Moore Original Duffle Bag is a spacious, well-constructed cricket bag suiting a variety of playing levels,… https://t.co/nxt8pSk1EB
#
# The Kookaburra Ghost Cricket Bat is an absolute monster! A giant profile with minimal scalloping means even the lon… https://t.co/1Q5J3SnLnv
#
# The Gray-Nicolls Legend Cricket Bat offers players of all levels the opportunity to create your own history by reap… https://t.co/uEAoq6F3Mu
#
# Kookaburra Pro 2750 wheelie bag has a tapered design for greater stability in use as well as multiple pockets with… https://t.co/WBrOxsQoK7
#
# New Balance CK4040 cricket shoes are designed working with some of the world’s best bowlers this shoe delivers prot… https://t.co/pYH6LbE5Vs
#
# Congratulations to James Vince on being called back to the England Test side. He endorses the Gunn &amp; Moore Haze cri… https://t.co/qO8KYeHrbt
#
# Puma EvoSpeed bat collection sets a new benchmark to deliver high performance hitting power with a re-weighted bala… https://t.co/hyKdCwRNx0
#
# Gray-Nicolls Powerbow 6 batting gloves are a traditional glove shape with added foam for maximum movement, to offer… https://t.co/oUb6HwSYPD
#
# Slazenger V100 cricket bats are designed for the all-rounder, the V100 range offers an ultra-light weight bat with… https://t.co/CnFEJCIYn0
#
# Gray-Nicolls Kronus batting pads have an elegant design offering players a batting pad that provide light weight pr… https://t.co/tN4aMMXo2P
#
# The Gunn and Moore Zelos DXM cricket bats have a low to mid sweet spot on this blade which makes it perfect for bat… https://t.co/5UEekvWK32
#
# Gray Nicolls Kronus is the blade for any batsman looking to dominate the opposition. It holds a hidden destructive… https://t.co/d3cNgxwmRn
#
# Mimic the stars with a pair of Kookaburra Batting Gloves. Think pro-quality batting gloves. Think Kookaburra.… https://t.co/gRLvS0F7KH
#
# Gray Nicolls Atomic cricket helmet has a redesigned grille and peak offer greater resistance to frontal ball strike… https://t.co/X3St9m4R9y
#
# Oakley Radar® eyewear combined everything we learned from decades of research with the world’s best athletes, and w… https://t.co/xKsnTNjbjM
#
# The batsman can move in a more natural way, the Strippers just snug fit to become part of you. This translates to f… https://t.co/6AebsURdI2
#
# The Gunn &amp; Moore Haze cricket bat has a mid to high swell position for power play, allowing you to punish anything… https://t.co/WCr2sDkedt
#
# A Gray-Nicolls custom made cricket bat is your way of guaranteeing you get the highest quality cricket bat that tru… https://t.co/OsrkwsYcng
#
# Masuri helmets are british made and manufactured single shell protection, providing an affordable and lightweight h… https://t.co/M6BgUwEJuQ
#
# Whether you’re at the crease or running up to bowl, Asics Gel 100 Not Out cricket shoes will keep your feet comfort… https://t.co/fBf6wl6JzV
#
# New Balance TC batting gloves, tradition meets technology. The TC gloves are breathable and perfectly postioned spl… https://t.co/LxfBkBrqGL
#
# The Gray-Nicolls Legend Cricket Bat offers players of all levels the opportunity to create your own history by reap… https://t.co/P9Wao02e5X
#
# Asics Gel Advance 6 cricket shoes is a lightweight shoe that combines great cushioning and flexibility for the cric… https://t.co/QAkBKyz5Ef
#
# Gunn &amp; Moore Original Limited Edition batting gloves absorbs up to 90% of energy when impacted at high strain rates… https://t.co/qyNG9WXPI7
#
# The Surge provides a distinctive profile where the enhance toe allows for greater pick up. The stylish graphics has… https://t.co/yKdmU3YyE5
#
# Slazenger V600 Cricket Bats are carefully crafted to provide maximum edges to ensure power is delivered with every… https://t.co/HF0VLIEzqJ
#
# Gunn &amp; Moore 909 batting pads have XRD Extreme Impact Protection is flexible, brethable and lightweight.
# #GM2018 #… https://t.co/ZOvACAIGSd
#
# One of Gray Nicolls staple ranges, Powerbow 6 with a full blade profile making it an ideal bat for the classic well… https://t.co/HDI7nLdnlD
#
# With its unique design and smart storage pockets, the Kronus 400 Duffle Bag is versatille, manouverable and fuction… https://t.co/Xe8CF8nC4O
#
# Gain an edge in matches, training and recovery with a superior with Skins DNAmic Team long sleeve baselayer. Wear t… https://t.co/xUFbkEcY0A
#
# The Gunn and Moore 808 LE Batting Pads. The High Density Foam and Cane construction in this high quality batting pa… https://t.co/bVvH8t6SAY
#
# The Salix Raw T20 Cricket Bat has advanced profiling, pressing and shaping.
# #SalixBats #Salix… https://t.co/B5u6CTSHlu
#
# It’s powerful profile, big edges and world renowned graphics make no apologies, ideal for the stroke maker who like… https://t.co/9LL6nXi8Xb
#
# A medium sized bag , The Powerbow6 600 Bag is a fusion of innovation and fuctionality to optimise space and storage… https://t.co/sgr5fy61WU
#
# Gray-Nicolls Prestige batting pads has the leg-hugging design combined with "butterfly' padded straps and buckles o… https://t.co/EaqcAlcEQc
#
# Engineered for greater comfort and lighter weight without any compromise on protection. Shrey helmets offer increas… https://t.co/s2o47qg6vz
#
# Masuri Vision Series Cricket Helmets are lightweight, comfortable and have great ventilation, providing supreme pro… https://t.co/nzbIjsFawL
#
# @englandcricket  has released the squad for the 2nd test match against India @ Lord's. Who do you think will play?… https://t.co/unUlpUzHpu
#
# Gunn &amp; Moore 808 Batting Gloves has PU protection on the back of the hand and HD Foam in the finger rolls.
# #GM2018… https://t.co/HsVvhKE5Rx
#
# The exclusive range from West Indian Cricketer Carlos Brathwaite. Bringing you the first series from his collection… https://t.co/gdZXgCmp6K

# %% [markdown]
# # Find  the deals in the BestBuy_Deal tweets  that match products in SmartPortables MySQL product table

# %%
import re
import pymysql

cnx = pymysql.connect(user='root', password='deepak',
                              host='127.0.0.1',
                              database='csp584proj')
cursor = cnx.cursor()

query = ("SELECT Id FROM ProductDetails")
cursor.execute(query)


dealMatchGauranteed=[]
for product in cursor:
    for tweet in timeline:
        deal = (tweet['text'])
        if (len(re.findall('\s'+product[0]+'\s',deal)) >= 1):
            dealMatchGauranteed = dealMatchGauranteed + [deal]

# %%
# Sanity Test that  we got some deals
dealMatchGauranteed[:5]
# Out:
# ['The Puma EvoPower range optimises and aids perfomance with comfortable, technically superior products.\n#EvoPower… https://t.co/vjzh5k7Fi7',
#  'Limited time offer ending 10/09/18 - Save up to 25% on Puma Virat Kohli EvoSpeed 18.1 Cricket Shoes. USE CODE : SAV… https://t.co/jHPeR32I1v',
#  'The GM Chrome L555 bats have a traditional blade with massive contoured edges and a partially concaved back profile… https://t.co/zeY7flEX29',
#  'The GM Chrome L555 bats have a traditional blade with massive contoured edges and a partially concaved back profile… https://t.co/xOixhsoK02']

# %% [markdown]
# # Create and write the deals into DealMatches.txt file that will be used by web-app of SmartPortables to display two deal matches

# %%
dealMatchFile = open(r'C:\apache-tomcat-7.0.34\webapps\CricInfo\DealMatches1.txt', 'w')

for deal in dealMatchGauranteed:
  dealMatchFile.write("%s\n" % deal)

dealMatchFile.close()

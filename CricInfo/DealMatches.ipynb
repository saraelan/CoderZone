# %% [markdown]
# ### Objective

# %% [raw]
# Learn how to connect to social media network (we will use Twitter as example in this assignment), and collect/preprocess/analyze its data
#
#
# Tweets Data Can be used for different purposes by marketing department and data analytics team. For example:
#
# - Compete with rivals to offer price-match gaurantee policy
# - Offer same coupons like rivals in the market place

# %% [markdown]
# ### Installation and Setup

# %% [raw]
# For this assignment you need to do the following setup first:
#
# 1.  Create an account on twitter.com.
#
# 2.  Generate authentication tokens by following the instructions here :
#     https://dev.twitter.com/oauth/overview/application-owner-access-tokens
#
# 3.  Add your tokens to the credentials.txt file.

# %% [markdown]
# ### Twitter API

# %% [raw]
# Twitter API
#
# Two APIs:
#
#     REST API: Submit HTTP requests to access specific information (tweets, friends, ...)
#     Streaming API: Open a continuous connection to Twitter to receive real-time data.
#
# These APIs are  HTTP GET request
#
#
#
#
# Here are the twitter API docs that you must familiarize yourself with
#
# https://dev.twitter.com/rest/reference/get/followers/ids
#
# https://dev.twitter.com/overview/api/twitter-libraries

# %% [raw]
# When you search in a text (tweets are text messages), often you need to be aware of something STOP WORDS.
# You could read more about stop-words here:
#
#     https://en.wikipedia.org/wiki/Stop_words

# %% [markdown]
# # Lets create twitter object and use its API. Code snippets below will show you how to use this API

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterPager

# %%
o = TwitterOAuth.read_file(r'C:\apache-tomcat-7.0.34\webapps\CricInfo\credentials.txt')

# %%
o.access_token_key
# Out:
# '1058753351050018817-vdNLxtwWzh2y62yaN1B80ijJJqfJww'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(builtins.object)
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL string (ex. "https://USER:PASSWORD@SERVER:PORT"),
#  |                    or dict of URLs (ex. {'http':'http://SERVER', 'https':'https://SERVER'})
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A valid Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(resource, params=None, files=None, method_override=None) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A valid Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.
print(type(response))
dir(response)
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_quota',
#  'headers',
#  'json',
#  'response',
#  'status_code',
#  'stream',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x000002A27F87F908>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 200

# %%
tweets = [r for r in response]

# %%
print('found %d tweets' % len(tweets))
# Out:
# found 15 tweets

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[0]
# Out:
# {'created_at': 'Sat Nov 17 04:19:30 +0000 2018',
#  'id': 1063647792495714304,
#  'id_str': '1063647792495714304',
#  'text': "Want to work at DELL? We're #hiring in #Canberra, ACT! Click for details: https://t.co/vbJVIAqruB #DellJobs #IT #Job #Jobs #CareerArc",
#  'truncated': False,
#  'entities': {'hashtags': [{'text': 'hiring', 'indices': [28, 35]},
#    {'text': 'Canberra', 'indices': [39, 48]},
#    {'text': 'DellJobs', 'indices': [98, 107]},
#    {'text': 'IT', 'indices': [108, 111]},
#    {'text': 'Job', 'indices': [112, 116]},
#    {'text': 'Jobs', 'indices': [117, 122]},
#    {'text': 'CareerArc', 'indices': [123, 133]}],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/vbJVIAqruB',
#     'expanded_url': 'http://bit.ly/2wKQ2J6',
#     'display_url': 'bit.ly/2wKQ2J6',
#     'indices': [74, 97]}]},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://www.careerarc.com" rel="nofollow">CareerArc 2.0</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 41196169,
#   'id_str': '41196169',
#   'name': 'TMJ-AUC Jobs',
#   'screen_name': 'tmj_auc_jobs',
#   'location': 'Canberra, Australia',
#   'description': 'Follow this account for geo-targeted Other job tweets in Canberra, Australia. Need help? Tweet us at @CareerArc!',
#   'url': 'https://t.co/DByWt45HZj',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/DByWt45HZj',
#       'expanded_url': 'http://www.careerarc.com/job-seeker',
#       'display_url': 'careerarc.com/job-seeker',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 666,
#   'friends_count': 486,
#   'listed_count': 91,
#   'created_at': 'Tue May 19 20:02:00 +0000 2009',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 198,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '253956',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/691169297461170177/xtquaN-v_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/691169297461170177/xtquaN-v_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41196169/1453622578',
#   'profile_link_color': '4A913C',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '407DB0',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': {'type': 'Point', 'coordinates': [-35.3075, 149.124417]},
#  'coordinates': {'type': 'Point', 'coordinates': [149.124417, -35.3075]},
#  'place': {'id': '01e4b0c84959d430',
#   'url': 'https://api.twitter.com/1.1/geo/id/01e4b0c84959d430.json',
#   'place_type': 'city',
#   'name': 'Canberra',
#   'full_name': 'Canberra, Australian Capital Territory',
#   'country_code': 'AU',
#   'country': 'Australia',
#   'contained_within': [],
#   'bounding_box': {'type': 'Polygon',
#    'coordinates': [[[148.9959216, -35.480260417],
#      [149.263643456, -35.480260417],
#      [149.263643456, -35.147699163],
#      [148.9959216, -35.147699163]]]},
#   'attributes': {}},
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'lang': 'en'}

# %%
help(tweets[0])
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if D has a key k, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Returns a new dict with keys from iterable and values equal to value.
#  |
#  |  get(...)
#  |      D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(...)
#  |      D.setdefault(k[,d]) -> D.get(k,d), also set D[k]=d if k not in D
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %%
tweets[0]['text']
# Out:
# "Want to work at DELL? We're #hiring in #Canberra, ACT! Click for details: https://t.co/vbJVIAqruB #DellJobs #IT #Job #Jobs #CareerArc"

# %%
tweets[0]['created_at']
# Out:
# 'Sat Nov 17 04:19:30 +0000 2018'

# %%
tweets[0]['text']
# Out:
# "Want to work at DELL? We're #hiring in #Canberra, ACT! Click for details: https://t.co/vbJVIAqruB #DellJobs #IT #Job #Jobs #CareerArc"

# %%
tweets[0]['user']
# Out:
# {'id': 41196169,
#  'id_str': '41196169',
#  'name': 'TMJ-AUC Jobs',
#  'screen_name': 'tmj_auc_jobs',
#  'location': 'Canberra, Australia',
#  'description': 'Follow this account for geo-targeted Other job tweets in Canberra, Australia. Need help? Tweet us at @CareerArc!',
#  'url': 'https://t.co/DByWt45HZj',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/DByWt45HZj',
#      'expanded_url': 'http://www.careerarc.com/job-seeker',
#      'display_url': 'careerarc.com/job-seeker',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 666,
#  'friends_count': 486,
#  'listed_count': 91,
#  'created_at': 'Tue May 19 20:02:00 +0000 2009',
#  'favourites_count': 0,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 198,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '253956',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/691169297461170177/xtquaN-v_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/691169297461170177/xtquaN-v_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/41196169/1453622578',
#  'profile_link_color': '4A913C',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '407DB0',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))
# Out:
# screen_name=tmj_auc_jobs, name=TMJ-AUC Jobs, location=Canberra, Australia

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print('found %d followers for %s' % (len(followers), screen_name))
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines
# Out:
# found 200 followers for tmj_auc_jobs

# %%
print(followers[0]['screen_name'])
# Out:
# centerity

# %% [markdown]
# ##  Limitations:       Can only search 2 weeks in past         But can get up to 3,200 most recent tweets of a user     Rate limits! https://dev.twitter.com/docs/rate-limiting/1.1/limits         e.g., 180 requests in 15 minute window

# %% [markdown]
# # Get BestBuy timeline for the deals screen-name
#
# # This is the screen name for BestBuy_Deals

# %%
# Get BestBuyDeals timeline = ''
screen_name = 'ESPNcric_stats'
timeline = [tweet for tweet in twitter.request('statuses/user_timeline',
                                                {'screen_name': screen_name,
                                                 'count': 200})]
print('got %d tweets for user %s' % (len(timeline), screen_name))
# Out:
# got 200 tweets for user ESPNcric_stats

# %%
# Print time got created.

timeline[3]['created_at']
# Out:
# 'Mon Nov 12 09:40:05 +0000 2018'

# %%
# Print the text.
print('\n\n\n'.join(t['text'] for t in timeline))
# Out:
# No. of centuries in England's 2nd inns for Joe Root:
#
# First 73 Tests - one century
# Last 3 Tests - two centuries
#
# #SLvEng
#
#
# Brendon Taylor becomes the first Zimbabwe batsman to score centuries in both innings of a Test TWICE. He had done i… https://t.co/XR53M580Le
#
#
# Sam Curran averages more than 40 with the bat and less than 25 with the ball.
#
# #SLvEng
#
#
# 18 years after Aminul Islam's 535 minute innings against India in their First ever Test Mushfiqur Rahim breaks the… https://t.co/7isuuenmz5
#
#
# Mushfiqur Rahim is the first keeper to score 2 double centuries in Tests and also the first batsmen to score a doub… https://t.co/UKZe8kSNxa
#
#
# The victory in Chennai was India's third last-ball victory in T20Is when chasing.
#
# https://t.co/JIwjrjLs6k
#
# #IndvWI
#
#
# First time in T20Is that India haven't taken a wicket in the last 7 overs of the innings (14th to 20th).
#
# #INDvWI
#
#
# Mominul Haque and Mushfiqur Rahim bring up Bangladesh's highest stand for the fourth wicket in Tests https://t.co/HZx2T4K1Bv #BANvZIM
#
#
# Australia conceded 174 runs from their last-15 overs – the most they have conceded in these overs since 2001 in ODIs #AUSvSA #AUSvRSA
#
#
# Faf du Plessis and David Miller put together the third-highest partnership for South Africa in ODIs… https://t.co/mx8WTqpQtD
#
#
# That 48th over of South Africa's innings was the most expensive over by Mitchell Starc in international cricket. #AUSvsSA #AUSvIND
#
#
# This is now the highest partnership for South Africa against Australia in ODIs - https://t.co/HJyxuQ8QMt #AUSvSA #AUSvRSA
#
#
# This du Plessis-Miller stand is the highest for South Africa for any wicket in ODIs against Australia in Australia.… https://t.co/Pt885567ae
#
#
# Aiden Markram has scored 30+ six times &amp; 20+ ten times since his fifty on debut, in 15 ODI innings. He is yet to ad… https://t.co/tbyLn8MyO5
#
#
# Moeen Ali v Sri Lanka:
#
# In Eng - 5 wkts in 5 Tests, ave 72.70
# In SL - 8* wkts in 1 Test, ave 15.75*
#
# #SLvEng
#
#
# Max % of LBW dismissals since the Debut of Finch in ODIs( min 70 innings)
#
# AJ FINCH-15.4
# HM Amla-15.1
# JP Duminy-14… https://t.co/a5gL9hrecd
#
#
# Ben Foakes scores a hundred on debut- He is the
# 1) 5th Keeper
# 2) 5th batsmen to do so against Sri Lanka in Sri La… https://t.co/aMwJnZcmhS
#
#
# Rohit Sharma's sixth ton in T20 cricket. Only Gayle, Klinger, McCullum and Wright have more.
#
# #IndvWI
#
#
# Rohit Sharma brings up his fourth T20I century, the most by any batsman.
#
# #IndvWI
#
#
# 19th fifty-plus score for Rohit Sharma in T20Is, the most by a batsman, going past Virat Kohli's 18 such scores.… https://t.co/tE8thMIRmK
#
#
# Rohit-Dhawan become the most prolific pair in T20Is, going past Warner-Watson's aggregate of 1154 runs.
#
# https://t.co/nZxjGPlXou
#
# #IndvWI
#
#
# India's powerplay:
#
# First 4 overs - 20 runs, 1 boundary
# Last 2 overs - 29 runs, 4 boundaries
#
# #IndvWI
#
#
# Rohit Sharma becomes the highest run-getter for India in T20Is, edges past Kohli's tally of 2102.
#
# https://t.co/GjdwRAnXnv
#
# #IndvWI
#
#
# Zimbabwe complete their first away Test win since 2001. Also, their first Test win anywhere since 2013.
#
# #BanvZim
#
#
# Rangana Herath completes 100 Test wickets at Galle.
#
# Only Muralitharan (3 venues) and Anderson have done it before… https://t.co/ffqxmYNUDm
#
#
# Babar Azam became the fastest batsman to complete 1000 runs in T20Is, bettering Virat Kohli.
#
# Records page:… https://t.co/DuCW4yLE6B
#
#
# Carlos Brathwaite's economy of 2.75 is the best by a WI fast bowler in a four-over spell in T20Is https://t.co/X4RHnPAwgy
#
# #IndvWI
#
#
# 109/8 is West Indies' fourth-lowest first innings score in T20Is https://t.co/xskka6NYYO
#
# #IndvWI
#
#
# It is the first time West Indies have lost four wickets inside first 10 overs against India in T20Is.
#
# #IndvWI
#
#
# RT @ESPNcric_stats: Best bowling average in Powerplay overs in T20s in 2018 (Min. 120 balls):
#
# 15.35* Umesh Yadav
# 15.38 Mohd Irfan
# 15.98 Lo…
#
#
# Best bowling average in Powerplay overs in T20s in 2018 (Min. 120 balls):
#
# 15.35* Umesh Yadav
# 15.38 Mohd Irfan
# 15.9… https://t.co/s78Y0Hv9yb
#
#
# Australia's seventh straight loss in ODIs - Their worst streak ever beating their six successive losses between 7th… https://t.co/WnmaTeLJ9j
#
#
# 152- Australia's lowest Score batting first against SA at home - the top 3 scores have come at Perth -https://t.co/R3WE9o4kxQ #AUSvSA
#
#
# Only three other bowlers have got to 150 ODI wickets quicker than Imran Tahir. Saqlain Mushtaq (78 matches), Brett… https://t.co/ZhdN0tAzLF
#
#
# Irrespective of the scoreline at the end of the series, Australia are confirmed to have their worst year in ODIs ev… https://t.co/mgNskkUIxM
#
#
# Rohit Sharma becomes the seventh batsman to hit 200 or more sixes and he is the fastest to do so in terms of inning… https://t.co/fySg2PFDuw
#
#
# 104 is West Indies' lowest ever total against India in ODIs.
#
# https://t.co/usfmanaqzL
#
# #IndvWI
#
#
# The win by 224 runs is India's third-largest in ODIs and biggest in 10 years https://t.co/0iodVPNU0e
#
# #IndvWI
#
#
# Centuries by India's No. 4 batsmen since 2015:
#
# Manish Pandey, 104* v Aus, SCG, 2016
# Yuvraj Singh, 150 v Eng, Cutta… https://t.co/E17OlXSD6T
#
#
# Fastest to 21 ODI 100s:
#
# 116 H Amla
# 138 V Kohli
# 183 AB de Villiers
# 186 ROHIT SHARMA
# 200 S Tendulkar
#
# #IndvWI
#
#
# Rohit's century progression:
#
# First 50 runs - 60 balls
# Next 50 runs - 38 balls
#
# #IndvWI
#
#
# Virat Kohli has scored 23 centuries while chasing.
#
# His 107 in Pune is only the third in unsuccessful chase.… https://t.co/wS7VxVo932
#
#
# Virat Kohli is the first India player to score centuries in three consecutive ODI innings.
#
# List: https://t.co/d4TG6EyAZn
#
# #IndvWI
#
#
# West Indies' 6th wkt partnerships this series:
#
# 1st ODI: 60 - Hetmeyer &amp; Holder
# 2nd ODI: 47 - Hope &amp; Holder
# 2rd ODI… https://t.co/5qoV3hZ68I
#
#
# Marlon Samuels' score this series - 0, 13, 9.
#
# His average of 7.33 is his joint-worst in any ODI series in last 10… https://t.co/rmSys6LaV5
#
#
# 321 - the score at which the Vizag ODI tied - is the third-highest score to end in tie in ODIs.
#
# https://t.co/VLa5jppNbk
#
# #IndvWI
#
#
# Kohli's innings:
#
# First 50 runs - 56 balls
# Next 50 runs - 50 balls
# Last 57 runs - 23 balls
#
# #IndvWI
#
#
# Fastest to 1000 ODI runs in a year:
#
# 11 KOHLI (2018)
# 15 Amla (2010), Kohli (2012)
# 17 Gower (1983), Watson (2011), S… https://t.co/NztTLNkS3A
#
#
# Kohli becomes the fastest to 10,000 ODI runs.
#
# Records page: https://t.co/Vq3Buxaz6v
#
# #IndvWI
#
#
# Fastest to 20 ODI 100s:
#
# 108 H Amla
# 133 V Kohli
# 175 AB de Villiers
# 183 ROHIT SHARMA
# 197 S Tendulkar
#
# #IndvWI
#
#
# 5th 200+ partnership between Virat Kohli and Rohit Sharma. No other pair has more than 3.
#
# https://t.co/y7frz177gy
#
# #IndvWI
#
#
# Kohli brings up his 36th ODI ton and 60th across International formats.
#
# #IndvWI
#
#
# 11th 150+ partnership between Kohli and Rohit.
#
# Only Tendulkar-Ganguly have more.
#
# https://t.co/5Xvg6qRynV
#
# #IndvWI
#
#
# 322/8 is West Indies' fourth-highest ODI total against India and highest in 10 years.
#
# https://t.co/acDroHRqKe
#
# #IndvWI
#
#
# Marlon Samuels get a duck in his 200th ODI.
#
# His first duck against India, in 40 matches.
#
# #IndvWI
#
#
# Australia's Losses in 2018
#
# 6 Wickets vs SA
# 322 runs vs SA
# 492 runs Vs SA
# 373 runs vs Pak
#
# #AUSvPAK
#
#
# The win by 373 runs is Pakistan's biggest ever in Tests in terms of runs.
#
# https://t.co/RcjndxoV3j
#
# #PakvAus
#
#
# Mohammad Abbas becomes the first Pakistan fast bowler since Mohammad Asif in 2006 to pick a ten-wicket haul in Test… https://t.co/LQUl9nNY5V
#
#
# Three dismissals in 90s for a team in a Test:
#
# WI v Eng, PoS, 1935
# Eng v WI, Oval, 1995
# Aus v Ind, Nagpur, 2004
# Pak… https://t.co/DfMDt5yhh6
#
#
# Babar Azam has hit 3 sixes in this innings already.
#
# Before this in his Test career of 28 innings, he had hit only 2 sixes!
#
# #PakvAus
#
#
# Fakhar Zaman becomes the first Pakistan opener and fourth overall to score two 50+ scores on Test debut.
#
# https://t.co/Lqup6LKEDG
#
# #PakvAus
#
#
# 145 is Australia's fourth-lowest first innings total in Tests in Asia and lowest in UAE.
# https://t.co/lZPNRnB2D1
# #PakvAus
#
#
# Mohammad Abbas became the joint-fastest Pakistan pacer to 50 Test wickets, in 10 Tests.
#
# Waqar Younis, Shabbir Ahm… https://t.co/bC1KIDHeya
#
#
# Fakhar Zaman became the fourth Pakistan player to get out in 90s on Test debut.
#
# https://t.co/qBlzEfZNKh
#
# #PakvAus
#
#
# Nathan Lyon is the first spinner in last 10 years to take 4 wickets in the first session on first day of a Test match.
#
# #PakvAus
#
#
# Nathan Lyon picks 4 wickets in 6 balls and goes past Mitchell Johnson to become the fourth-highest wicket-taker for… https://t.co/FaAWxEaP2N
#
#
# Most consecutive Test series wins at home:
#
# 10 Australia - 1994-2000
# 10 Australia - 2004-2008
# 10* India - 2013-*
#
# #IndvWI
#
#
# Umesh Yadav becomes only the third India fast bowler to take a 10 wickets in a Test at home!
#
# https://t.co/oTADZV9X5G
#
# #IndvWI
#
#
# Umesh Yadav's bowling strike rate this year is the best for any India fast bowler in a calendar year taking 15+ wkt… https://t.co/E24qdrs2uU
#
#
# First time since 2000 both openers of the visiting team have got out for ducks in the same innings in India.… https://t.co/LzW7PpA5gB
#
#
# Jason Holder's bowling average of 11.87 this year is the best for any fast bowler in a calendar year in last 100 ye… https://t.co/MERkCzo0Kk
#
#
# The 56-run lead by India is their lowest against West Indies in the 8 Tests since 2013.
#
# Leads in last 7 Tests v W… https://t.co/MFozyTFAnI
#
#
# Malinga has 8 five-wicket hauls in ODIs. Only four bowlers have more - https://t.co/ZyEiuNOXJY #SLvENG
#
#
# Most runs between dismissals for England in ODIs -
#
# JOE ROOT             304*
# Graeme Hick          301
# Jason Roy… https://t.co/KOguSh3n2k
#
#
# Bairstow is the sixth batsmen from England to score over 1000 runs in a year in ODIs- https://t.co/KZDCxzf7aE #SLvENG
#
#
# India batsmen to hit a six in the first over of a Test inns since 2000:
#
# Virender Sehwag v SA, Ahmedabad, 2008
#
# Pri… https://t.co/OsMrLkMMna
#
#
# Umesh Yadav's 6 for 88 is the first six-wkt haul by an India pacer at home since 2000.
#
# Lasr was Javagal Srinath v… https://t.co/BTQp9b4cVv
#
#
# Second ton for Roston Chase against India. Only 3 batsmen have scored more hundreds against India at No.6 position… https://t.co/gyRi0kDTAy
#
#
# Chase-Holder is the first pair to share 3 century partnerships for 7th wkt in Test history.
#
# https://t.co/TUcnHJYMOc
#
# #IndvWI
#
#
# First time in 3 years all of WI's top-8 batsmen got into double-figure scores.
#
# This is their first such instance… https://t.co/vC6hSZ0PnU
#
#
# West Indies' scores in India in last 2 Test series:
#
# 2013: 234, 168, 182, 187
# 2018: 181, 196 and now 150/5
#
# Only on… https://t.co/qh6dOLEXIQ
#
#
# Australia survive against Pakistan playing out 139.5 overs- Fourth longest fourth innings in Asia - https://t.co/QBojVVFgeZ #PAKvAUS
#
#
# RT @ESPNcricinfo: The records keep tumbling for Usman Khawaja in Dubai
#
# https://t.co/lpcpDZNOJo #PAKvAUS https://t.co/giup7m4KHn
#
#
# Australia now have the highest fourth innings score for a visiting team in the UAE going past the 322 made by Windi… https://t.co/edniE3EBnn
#
#
# Usman Khawaja has the highest score in the 4th innings in UAE going past the unbeaten 131 scored by Younis Khan in… https://t.co/tujflGmPdE
#
#
# Usman Khawaja is just the fifth player from Australia to score a fourth innings century in Asia -https://t.co/bnMrr09wLO #PAKvAUS
#
#
# First time in eight Tests a wicket hasn't fallen in the morning session on the fifth day in Dubai . #AUSvPAK
#
#
# The 132 runs added by Head &amp; Khawaja broke a couple of records
#
# 1) Highest 4th innings stand for Australia in Asia… https://t.co/slYJ9e1AXV
#
#
# First time in 20 years, Australia have had 4 or more ducks from top-6 batsmen in a Test.
#
# Head, Labushagne and Mar… https://t.co/oKUBDr2kSU
#
#
# 42 runs scored by Australia's Nos.3-11, the 3rd-lowest ever in their Test history, and their lowest in the 1st inni… https://t.co/2U1tRtXUbU
#
#
# Bilal Asif is the oldest to take a five-wicket haul on Test debut in the last 50 years.
#
# https://t.co/yV5Q8yI2yW
#
# #PakvAus
#
#
# Bilal Asif is the 11th Pakistan bowler to take a five-wicket haul on Test debut. https://t.co/dgpAVwwGh6
#
# #PakvAus
#
#
# Only the 6th instance in the last 100 years of two debutants in the top 6 getting ducks in an innings; 2 of them ha… https://t.co/b9Y74pg3aZ
#
#
# Australia's 142-run opening stand:
#
# - Their second-highest in Asia
# - Second-highest for any team v Pak in UAE
#
# #PakvAus
#
#
# Pakistan find the first wicket in the 52nd over.
#
# It was the first time in UAE that they had to wait more than 50… https://t.co/51trVr7KqI
#
#
# First century opening stand for Australia in Asia in about 4 years in 22 inns.
#
# Last was also in UAE, in Oct 2014… https://t.co/GRHpDqpVmD
#
#
# Only the second instance of century opening stands for both teams in their first inns in Tests in UAE.
#
# First was… https://t.co/OpTG44tq0I
#
#
# A 205 run opening stand between Hafeez and Imam - Fifth best opening stand for Pakistan and only the third instance… https://t.co/sw5XATPM5c
#
#
# In the last 10 years Australia have handed out caps to 51 players - Most by any team. The preceding 10 years saw Au… https://t.co/qR7YMdq19r
#
#
# RT @ESPNcricinfo: It's been quite the wait for Aaron Finch!
#
# https://t.co/YUIJjZDFjh #PAKvAUS
#
# (Note: Players from Afghanistan and Irelan…
#
#
# India players to win Man of the Match on their Test debut:
#
# Pravin Amre
# RP Singh
# R Ashwin
# Shikhar Dhawan
# Rohit Sharma
# PRITHVI SHAW
#
# #IndvWI
#
#
# The win by an innings &amp; 272 runs is India's biggest ever in Tests.
#
# https://t.co/Gi934BCjyc
#
# #IndvWI
#
#
# Five-wicket hauls in all 3 International formats:
#
# Tim Southee
# Lasith Malinga
# Ajanta Mendis
# B Kumar
# Umar Gul
# Imran… https://t.co/kBTMmTTP4c
#
#
# Lead of 468 runs is the third-highest first innings lead for India in Tests.
#
# https://t.co/H4imEQFrcf
#
# #IndvWI
#
#
# 649/9 is India's highest total against West Indies in Tests.
#
# https://t.co/cVDm8Ur7FW
#
# #IndvWI
#
#
# Bishoo has now conceded 180+ runs - the most by any West Indies bowler against India and fourth-most for WI in an i… https://t.co/A1uLW4rg5B
#
#
# Most 500+ totals at home since 2016:
#
# 8 India
# 4 Australia
# 2 Eng, NZ, SA
# 1 Bdesh
#
# #IndvWI
#
#
# Virat Kohli becomes the first India batsman to score 1000+ Test runs in three successive years.
#
# Only Hayden (5 ye… https://t.co/kOjprD2q8H
#
#
# Rishabh Pant missed becoming the first Indian wicketkeeper to score centuries in successive innings in Tests.
#
# #IndvWI
#
#
# Kohli is now the fourth-most century scorer for India in Tests, goes past Sehwag's 23 100s.
#
# Records page: https://t.co/3PIzHMFUUh
#
# #IndvWI
#
#
# 24 Test centuries for Kohli in 123 innings.
#
# Only Don Bradman got there in fewer inns (66).
#
# #IndvWI
#
#
# Prithvi Shaw becomes the youngest Indian and fourth youngest overall to score century on Test debut.
#
# https://t.co/eGt0ytCGuj
#
# #IndvWI
#
#
# Prithvi Shaw becomes the youngest Indian to score a fifty on Test debut.
#
# https://t.co/2u56iTKgkN
#
# #IndvWI
#
#
# No. of Test centuries:
# WI playing XI - 18
# Virat Kohli - 23
#
# No. of Test wickets:
# WI playing XI - 271
# R Ashwin - 327
#
# #IndvWI
#
#
# Prithvi Shaw is the youngest debutant (18y 329d) for India in Tests in last 10 years.
#
# https://t.co/BFI2h0ACtU
#
# #IndvWI
#
#
# The 223-run chase is the highest for India without an individual fifty-plus score.
#
# https://t.co/SgijlehKER
#
# #IndvBan #AsiaCup2018Final
#
#
# Mehidy Hasan Miraz becomes the first ever Bangladesh player to open the batting and bowling in an ODI.
#
# Last playe… https://t.co/O4ZMYHIikJ
#
#
# Bangladesh's innings:
#
# First 100 runs - 17.5 overs (107 balls)
#
# Next 100 runs - 26.5 overs (158 balls)
#
# #IndvBan #AsiaCupFinal
#
#
# Liton Das got to his century in the 29th over - the earliest any Bangladesh batsman has completed a century.
#
# Prev… https://t.co/AZM8Zu0sz7
#
#
# Liton Das' 33-ball fifty is the second-fastest against India in finals.
#
# Fastest is 32 balls by Symonds in 2003-04… https://t.co/sjr2KACeen
#
#
# Bangladesh have not won any knockout match in ODIs, before today.
#
# They have played five and lost all five. Two aga… https://t.co/4669PD6ibL
#
#
# Mushfiqur Rahim became the first Bangladesh batsman to get out on 99 in ODIs.
#
# He's also only the 7th wicketkeeper… https://t.co/BG4bIuSGZD
#
#
# India's 8th Tied result in ODIs and Afghanistan's first.
#
# https://t.co/HBibZpxw4o
#
# #IndvAfg #AsiaCup
#
#
# The 110-run opening stand between Rahul and Rayudu is the 100th century opening stand for India in ODIs - the first… https://t.co/TDvkAfCqZM
#
#
# Dhawan and Rohit's centuries are the 7th instance when both India openers have scored centuries and only the 2nd su… https://t.co/0x8aJqERqm
#
#
# Rohit Sharma became the fifth-fastest batsman to reach 7000 ODI runs.
#
# https://t.co/iPCAcxxWTp
#
# #IndvPak #AsiaCup
#
#
# 13 opening century stands for Rohit and Dhawan - Second most for India behind Sachin Tendulkar and Saurav Ganguly w… https://t.co/ADJPwcPYz7
#
#
# 22 runs off Bhuvneshwar's over - his most expensive over of ODI career.
#
# #AsiaCup #IndvPak
#
#
# Shoaib Malik is now the 4th highest run-getter in #AsiaCup. Only Jayasuriya, Sangakkara and Tendulkar have scored m… https://t.co/LYSi6iqrug
#
#
# Last time Pakistan finished a successful chase in the last over (50th over) was in Dec 2014.
#
# https://t.co/ZwTxlwNN71
#
# #AsiaCup #PakvAfg
#
#
# Bangladesh batsmen averaging under 18 this Asia Cup - their lowest in any series/tournament in four years.… https://t.co/iPIIvDvG8C
#
#
# The last time @imjadeja took three wickets in an ODI was way back in 2014 against West Indies. He has come back strongly. #AsiaCup
#
#
# In the last 35 ODIs Rashid Khan has gone wicketless only twice and averages 12.07 striking once every three overs. #AsiaCup
#
#
# This is India's best win while chasing against Pakistan - 126 balls remaining - https://t.co/p29aXpQemn #AsiaCup
#
#
# Pakistan's lowest score in the UAE this decade while batting first is 198 - They will need a special effort to get… https://t.co/q5fGz5eHcV
#
#
# First 100 run opening stand India have conceded in almost a year. Previous instance was when Australia  toured Indi… https://t.co/7TgH2FAzgl
#
#
# Pant and Rahul's partnership completes 200 runs.
#
# - Second ever for India in 4th inns
# - Second for any team for 6th wkt or lower
#
# #EngvInd
#
#
# Rishabh Pant is the youngest Indian to score a Test century since 2002.
#
# https://t.co/qq3bVgxHWQ
#
# #EngvInd
#
#
# The Rahul-Pant stand is the highest ever 6th wkt p'ship for India in 4th inns of Tests, beating the 136-run stand b… https://t.co/LEXpjRqBbQ
#
#
# Indian batsmen v Short &amp; Short good length deliveries in this 4th inns:
#
# Rahul - 32 off 30 balls
# Others - 11 off 22… https://t.co/c9Li6uX7by
#
#
# KL Rahul is only the second Indian opener to score a century in the 4th inns in England.
#
# Only one before this was… https://t.co/n8sxMYLb1q
#
#
# The partnership between Rahul and Rahane is only the second century stand for 4th wicket after a team being three-d… https://t.co/qprrNQ2TN4
#
#
# With a 7500-ball cut-off, only 2 England batsmen have faced more balls per dismissal since 1980 than Alastair Cook.… https://t.co/ArHcJjWTVD
#
#
# Lowest score at fall of 3rd wicket for India:
#
# 0 v Eng, Leeds, 1952
# 2 v NZ, Ahmedabad, 2010
# 2 v Eng, The Oval, 2018… https://t.co/12eFo5nxPh
#
#
# First time this year two England batsmen have scored 100s in the same Test innings, in 18 innings.
#
# https://t.co/Q1LSYwsdA8
#
# #EngvInd
#
#
# Alastair Cook becomes the most prolific run-getter among left-handed batsmen in Test cricket history, going past Ku… https://t.co/PwnYpULQ4v
#
#
# Alastair Cook is only the second player to scored 50+ in both innings of his debut Test and final Test.
#
# First was… https://t.co/XuCmkyz709
#
#
# Virat Kohli completes 4000 Test runs as captain - first Indian to do so and 10th overall.
#
# He's the fastest to ach… https://t.co/uPCh0s1O0Z
#
#
# Kohli completes 500 runs in the series.
#
# No one else has got to 300 even.
#
# https://t.co/RG6QaMrQyy
#
# #EngvInd
#
#
# Can India do it?
#
# https://t.co/xuruZ1G78f
#
# #EngvInd
#
#
# India batsmen average 18.74 in fourth innings in last two years, the lowest among all teams.
#
# https://t.co/VmpUSIScIX
#
# #EngvInd
#
#
# Curran's runs tally in this series is the highest by any player at No. 8 or lower in a series against India. Prev:… https://t.co/G5M0g3mcVb
#
#
# England lead over 200.
#
# The last time India successfully chased down 200 in Tests outside Asia was at Adelaide in… https://t.co/ClqjuWHyhv
#
#
# Alastair Cook's average has dropped below 45 for the first time in about 8 years.
#
# #EngvInd
#
#
# No. of partnerships of 30+ runs in this #EngvInd series:
#
# 1st &amp; 2nd wkts - 7 partnerships
# 9th &amp; 10th wkts - 8 partnerships
#
# #EngvInd
#
#
# Rishabh Pant's duck off 29 balls is the joint-longest duck for India in Tests. https://t.co/gV6nnam6DC
#
# #EngvInd
#
#
# Virat Kohli became the second-fastest India batsman to complete 6000 Test runs in 119 innings.
# https://t.co/YN0EGf58NK
# #EngvInd
#
#
# England lost 4 wkts for 36 runs - their 2nd-lowest score at fall of 4 wkts v India at home.
#
# https://t.co/kjm4IoFs0G
#
# #EngvInd
#
#
# Strike Rate of India's pace bowlers in this series is the best for any visiting team in England in over 100 years.… https://t.co/tzUDNeNJsQ
#
#
# 17.70 - Average of England's top-4 batsmen in this series - their worst in any series in last 80 years.
#
# #EngvInd
#
#
# Ishant Sharma got his 250th wicket in his 86th Test - the slowest among specialist bowlers.
#
# Kallis had taken 127… https://t.co/HserOjYAHT
#
#
# Incidentally, India's sequence of changing XIs began from the Southampton Test of 2014 and after 4 years at the sam… https://t.co/4iCsHxKyfr
#
#
# India are playing with an unchanged XI for the first time under Kohli's captaincy. #EngvAus
#
#
# India's win by 203 runs is only the sixth instance of a team winning by 200+ runs in the third Test after losing th… https://t.co/5AKLXYo5un
#
#
# The win by 203 runs is India's third-largest over England https://t.co/u6BElWtoqY
#
# #EngvInd
#
#
# Butter-Stokes' stand of 169 runs:
#
# - Highest for any team in 4th inns after being 4-down for &lt;100
# - Highest 5th wkt… https://t.co/Abg6XuVt41
#
#
# And that's England's biggest 5th-wkt partnership in the 4th innings in their Test history, going past a 65-year-old… https://t.co/LGjChEVoS5
#
#
# The Trent Bridge Test is the first ever Test in the history where the top-five batsmen reached double-figures in al… https://t.co/m4CkSjepqK
#
#
# The target for England in this Test will be the highest ever set by India against them.
#
# Previous: Target of 500 a… https://t.co/FisryCVN68
#
#
# Quickest to 23 Test centuries (inns):
#
# 59 Bradman
# 109 Gavaskar
# 110 S Smith
# 118 KOHLI
# 122 Yousuf
#
# #EngvInd
#
#
# 430* runs in this series for Kohli - the most by an Indian captain in a Test series in England, going past Azharudd… https://t.co/RzjQtM7Gm0
#
#
# Virat Kohli has been part of six of the last seven century partnerships for India in Tests in Eng/Aus/NZ/SA.
#
# #EngvInd
#
#
# 50+ opening partnerships for India in both innings of a Test in Eng/Aus/SA/NZ:
#
# Merchant-Mushtaq Ali, Oval, 1936
# En… https://t.co/JoUIgBsvxn
#
#
# First time since 1986 Indian openers have managed two 50+ partnerships in a Test in England/Australia/South Africa/… https://t.co/rzCJG1wcrC
#
#
# This is only the fourth ever instance where India have had two 50 plus opening stands in Australia, South Africa, E… https://t.co/faww3PnmVm
#
#
# Three times already teams have been bowled out within 50 overs in this series, which equals the most such instances… https://t.co/r7S5AzaEod
#
#
# England on Day 2:
#
# At Lunch: 46 for 0
# At Tea: 161 for 10
#
# #EngvInd
#
#
# First time since 2002 in a Test in England the top-six have all got to double-figures in the first innings of both… https://t.co/DZCdexkaaW
#
#
# 97 at Trent Bridge is only the second time Kohli has got out in the 90s in his Test career.
#
# The other was at Joha… https://t.co/8xs3bTAiXU
#
#
# Kohli-Rahane century stand:
#
# India's first in two tours this year (SA &amp; Eng)
#
# India's first since Bhuvneshwar-Shami's in 2014.
#
# #EngvInd
#
#
# First time since 2011 India's top-5 have all passed double-figures in an inns in England, i.e after 7 Tests and 14… https://t.co/Jsq5IFzSgz
#
#
# Average 1st-wkt stand in the first inns of a Trent Bridge Test in the last 10 matches before this one: 16 (highest… https://t.co/8j6MK7tGIe
#
#
# Rishabh Pant becomes the 5th youngest Indian wicket-keeper to make his debut in Tests.
#
# Parthiv Patel, Dinesh Kart… https://t.co/KdksD7H64I
#
#
# 33* - India's top score in this Test, their fifth-lowest in all result Tests for them: https://t.co/l3u7az6SIm #ENGvIND
#
#
# 4.77 - Ratio between Ind's bowling ave (56.57) and batting ave (11.85) in this Test... makes it into the top 10 of… https://t.co/zcx4qZ2hdn
#
#
# 4.77 - ratio between India's bowling ave (56.57) and their batting ave (11.85). Makes it into the top ten in terms… https://t.co/eEJvqfTxLa
#
#
# 18 runs by Indian openers in this Test is their lowest since Kingston 2006 https://t.co/X8nOjJghgi
#
# #EngvInd
#
#
# Anderson has become the first fast bowler and only the second after Muralitharan to take 100 Test wickets at a venu… https://t.co/qAqPtmUrmd
#
#
# Pairs by openers at Lord's:
#
# A Bannerman, 1988
# C Roach, 1933
# J McGlew, 1955
# J Wright, 1986
# Saleem Elahi, 2001
# M VIJAY, 2018
#
# #EngvInd
#
#
# England's results at Lord's after taking first innings lead of &gt;200:
#
# Won 26
# Drawn 6
# Lost 0
#
# #EngvInd
#
#
# Totals of teams batting first at Lord's in 3 recent Tests:
#
# 123 WIndies, 2017 (57.3) - Lost
# 184 Eng v Pak, 2018 (58… https://t.co/LVx6fBFlT4
#
#
# 11th time Kohli has scored 200 or more runs in a Test match, most among Indians. Tendulkar and Dravid did it 10 times.
#
# #EngvInd
#
#
# Vijay's 2nd-inngs problems continue: he averages 51.48 in the 1st innings, and 25 in the 2nd. In his last 10 second… https://t.co/Cj4KxS3Yju
#
#
# Since the start of 2014, Ishant has 72 wkts from 19 away Tests, the most wkts by an India bowler. Average less than… https://t.co/Wt7m6rUHiQ
#
#
# Ishant Sharma is the first Indian since Kumble at Adelaide in 2003 to take 3 wickets in an over outside Asia.
#
# #EngvInd
#
#
# Six wickets this Test is already the most Ashwin has taken in a Test in Eng/Aus/SA/NZ.
#
# #EngvInd
#
#
# Ashwin v left-handers: 169 wkts, ave 19.37; v right-handers: 153 wickets, ave 31.36 #ENGvIND
#
#
# 15th century as captain for Kohli.
#
# Only Graeme Smith (25) and Ponting (19) have more.
#
# https://t.co/neK9tqePLk
#
# #EngvInd
#
#
# Kohli's control % in the 2014 series in Eng: 80.5%; his control % in this innings: 75.6%. Yet, in 2014 he scored 13… https://t.co/0GtXOUsXfO
#
#
# Kohli gets past 40, his highest score in Tests in England.
#
# He averaged just 13.40 in the 2014 England tour with highest of 39.
#
# #EngvInd

# %%
# Count words
from collections import Counter  # This is just a fancy dict mapping from object->int, starting at 0.
counts = Counter()
for tweet in timeline:
    counts.update(tweet['text'].lower().split())
print('found %d unique terms in %d tweets' % (len(counts), len(timeline)))
counts.most_common(10)
# Out:
# found 1333 unique terms in 200 tweets
# [('in', 228),
#  ('the', 171),
#  ('-', 62),
#  ('first', 61),
#  ('is', 57),
#  ('for', 54),
#  ('to', 54),
#  ('of', 51),
#  ('test', 50),
#  ('a', 49)]

# %%
import re
for tweet in timeline:
    deal = tweet['text']
    print(deal + '\n')
# Out:
# No. of centuries in England's 2nd inns for Joe Root:
#
# First 73 Tests - one century
# Last 3 Tests - two centuries
#
# #SLvEng
#
# Brendon Taylor becomes the first Zimbabwe batsman to score centuries in both innings of a Test TWICE. He had done i… https://t.co/XR53M580Le
#
# Sam Curran averages more than 40 with the bat and less than 25 with the ball.
#
# #SLvEng
#
# 18 years after Aminul Islam's 535 minute innings against India in their First ever Test Mushfiqur Rahim breaks the… https://t.co/7isuuenmz5
#
# Mushfiqur Rahim is the first keeper to score 2 double centuries in Tests and also the first batsmen to score a doub… https://t.co/UKZe8kSNxa
#
# The victory in Chennai was India's third last-ball victory in T20Is when chasing.
#
# https://t.co/JIwjrjLs6k
#
# #IndvWI
#
# First time in T20Is that India haven't taken a wicket in the last 7 overs of the innings (14th to 20th).
#
# #INDvWI
#
# Mominul Haque and Mushfiqur Rahim bring up Bangladesh's highest stand for the fourth wicket in Tests https://t.co/HZx2T4K1Bv #BANvZIM
#
# Australia conceded 174 runs from their last-15 overs – the most they have conceded in these overs since 2001 in ODIs #AUSvSA #AUSvRSA
#
# Faf du Plessis and David Miller put together the third-highest partnership for South Africa in ODIs… https://t.co/mx8WTqpQtD
#
# That 48th over of South Africa's innings was the most expensive over by Mitchell Starc in international cricket. #AUSvsSA #AUSvIND
#
# This is now the highest partnership for South Africa against Australia in ODIs - https://t.co/HJyxuQ8QMt #AUSvSA #AUSvRSA
#
# This du Plessis-Miller stand is the highest for South Africa for any wicket in ODIs against Australia in Australia.… https://t.co/Pt885567ae
#
# Aiden Markram has scored 30+ six times &amp; 20+ ten times since his fifty on debut, in 15 ODI innings. He is yet to ad… https://t.co/tbyLn8MyO5
#
# Moeen Ali v Sri Lanka:
#
# In Eng - 5 wkts in 5 Tests, ave 72.70
# In SL - 8* wkts in 1 Test, ave 15.75*
#
# #SLvEng
#
# Max % of LBW dismissals since the Debut of Finch in ODIs( min 70 innings)
#
# AJ FINCH-15.4
# HM Amla-15.1
# JP Duminy-14… https://t.co/a5gL9hrecd
#
# Ben Foakes scores a hundred on debut- He is the
# 1) 5th Keeper
# 2) 5th batsmen to do so against Sri Lanka in Sri La… https://t.co/aMwJnZcmhS
#
# Rohit Sharma's sixth ton in T20 cricket. Only Gayle, Klinger, McCullum and Wright have more.
#
# #IndvWI
#
# Rohit Sharma brings up his fourth T20I century, the most by any batsman.
#
# #IndvWI
#
# 19th fifty-plus score for Rohit Sharma in T20Is, the most by a batsman, going past Virat Kohli's 18 such scores.… https://t.co/tE8thMIRmK
#
# Rohit-Dhawan become the most prolific pair in T20Is, going past Warner-Watson's aggregate of 1154 runs.
#
# https://t.co/nZxjGPlXou
#
# #IndvWI
#
# India's powerplay:
#
# First 4 overs - 20 runs, 1 boundary
# Last 2 overs - 29 runs, 4 boundaries
#
# #IndvWI
#
# Rohit Sharma becomes the highest run-getter for India in T20Is, edges past Kohli's tally of 2102.
#
# https://t.co/GjdwRAnXnv
#
# #IndvWI
#
# Zimbabwe complete their first away Test win since 2001. Also, their first Test win anywhere since 2013.
#
# #BanvZim
#
# Rangana Herath completes 100 Test wickets at Galle.
#
# Only Muralitharan (3 venues) and Anderson have done it before… https://t.co/ffqxmYNUDm
#
# Babar Azam became the fastest batsman to complete 1000 runs in T20Is, bettering Virat Kohli.
#
# Records page:… https://t.co/DuCW4yLE6B
#
# Carlos Brathwaite's economy of 2.75 is the best by a WI fast bowler in a four-over spell in T20Is https://t.co/X4RHnPAwgy
#
# #IndvWI
#
# 109/8 is West Indies' fourth-lowest first innings score in T20Is https://t.co/xskka6NYYO
#
# #IndvWI
#
# It is the first time West Indies have lost four wickets inside first 10 overs against India in T20Is.
#
# #IndvWI
#
# RT @ESPNcric_stats: Best bowling average in Powerplay overs in T20s in 2018 (Min. 120 balls):
#
# 15.35* Umesh Yadav
# 15.38 Mohd Irfan
# 15.98 Lo…
#
# Best bowling average in Powerplay overs in T20s in 2018 (Min. 120 balls):
#
# 15.35* Umesh Yadav
# 15.38 Mohd Irfan
# 15.9… https://t.co/s78Y0Hv9yb
#
# Australia's seventh straight loss in ODIs - Their worst streak ever beating their six successive losses between 7th… https://t.co/WnmaTeLJ9j
#
# 152- Australia's lowest Score batting first against SA at home - the top 3 scores have come at Perth -https://t.co/R3WE9o4kxQ #AUSvSA
#
# Only three other bowlers have got to 150 ODI wickets quicker than Imran Tahir. Saqlain Mushtaq (78 matches), Brett… https://t.co/ZhdN0tAzLF
#
# Irrespective of the scoreline at the end of the series, Australia are confirmed to have their worst year in ODIs ev… https://t.co/mgNskkUIxM
#
# Rohit Sharma becomes the seventh batsman to hit 200 or more sixes and he is the fastest to do so in terms of inning… https://t.co/fySg2PFDuw
#
# 104 is West Indies' lowest ever total against India in ODIs.
#
# https://t.co/usfmanaqzL
#
# #IndvWI
#
# The win by 224 runs is India's third-largest in ODIs and biggest in 10 years https://t.co/0iodVPNU0e
#
# #IndvWI
#
# Centuries by India's No. 4 batsmen since 2015:
#
# Manish Pandey, 104* v Aus, SCG, 2016
# Yuvraj Singh, 150 v Eng, Cutta… https://t.co/E17OlXSD6T
#
# Fastest to 21 ODI 100s:
#
# 116 H Amla
# 138 V Kohli
# 183 AB de Villiers
# 186 ROHIT SHARMA
# 200 S Tendulkar
#
# #IndvWI
#
# Rohit's century progression:
#
# First 50 runs - 60 balls
# Next 50 runs - 38 balls
#
# #IndvWI
#
# Virat Kohli has scored 23 centuries while chasing.
#
# His 107 in Pune is only the third in unsuccessful chase.… https://t.co/wS7VxVo932
#
# Virat Kohli is the first India player to score centuries in three consecutive ODI innings.
#
# List: https://t.co/d4TG6EyAZn
#
# #IndvWI
#
# West Indies' 6th wkt partnerships this series:
#
# 1st ODI: 60 - Hetmeyer &amp; Holder
# 2nd ODI: 47 - Hope &amp; Holder
# 2rd ODI… https://t.co/5qoV3hZ68I
#
# Marlon Samuels' score this series - 0, 13, 9.
#
# His average of 7.33 is his joint-worst in any ODI series in last 10… https://t.co/rmSys6LaV5
#
# 321 - the score at which the Vizag ODI tied - is the third-highest score to end in tie in ODIs.
#
# https://t.co/VLa5jppNbk
#
# #IndvWI
#
# Kohli's innings:
#
# First 50 runs - 56 balls
# Next 50 runs - 50 balls
# Last 57 runs - 23 balls
#
# #IndvWI
#
# Fastest to 1000 ODI runs in a year:
#
# 11 KOHLI (2018)
# 15 Amla (2010), Kohli (2012)
# 17 Gower (1983), Watson (2011), S… https://t.co/NztTLNkS3A
#
# Kohli becomes the fastest to 10,000 ODI runs.
#
# Records page: https://t.co/Vq3Buxaz6v
#
# #IndvWI
#
# Fastest to 20 ODI 100s:
#
# 108 H Amla
# 133 V Kohli
# 175 AB de Villiers
# 183 ROHIT SHARMA
# 197 S Tendulkar
#
# #IndvWI
#
# 5th 200+ partnership between Virat Kohli and Rohit Sharma. No other pair has more than 3.
#
# https://t.co/y7frz177gy
#
# #IndvWI
#
# Kohli brings up his 36th ODI ton and 60th across International formats.
#
# #IndvWI
#
# 11th 150+ partnership between Kohli and Rohit.
#
# Only Tendulkar-Ganguly have more.
#
# https://t.co/5Xvg6qRynV
#
# #IndvWI
#
# 322/8 is West Indies' fourth-highest ODI total against India and highest in 10 years.
#
# https://t.co/acDroHRqKe
#
# #IndvWI
#
# Marlon Samuels get a duck in his 200th ODI.
#
# His first duck against India, in 40 matches.
#
# #IndvWI
#
# Australia's Losses in 2018
#
# 6 Wickets vs SA
# 322 runs vs SA
# 492 runs Vs SA
# 373 runs vs Pak
#
# #AUSvPAK
#
# The win by 373 runs is Pakistan's biggest ever in Tests in terms of runs.
#
# https://t.co/RcjndxoV3j
#
# #PakvAus
#
# Mohammad Abbas becomes the first Pakistan fast bowler since Mohammad Asif in 2006 to pick a ten-wicket haul in Test… https://t.co/LQUl9nNY5V
#
# Three dismissals in 90s for a team in a Test:
#
# WI v Eng, PoS, 1935
# Eng v WI, Oval, 1995
# Aus v Ind, Nagpur, 2004
# Pak… https://t.co/DfMDt5yhh6
#
# Babar Azam has hit 3 sixes in this innings already.
#
# Before this in his Test career of 28 innings, he had hit only 2 sixes!
#
# #PakvAus
#
# Fakhar Zaman becomes the first Pakistan opener and fourth overall to score two 50+ scores on Test debut.
#
# https://t.co/Lqup6LKEDG
#
# #PakvAus
#
# 145 is Australia's fourth-lowest first innings total in Tests in Asia and lowest in UAE.
# https://t.co/lZPNRnB2D1
# #PakvAus
#
# Mohammad Abbas became the joint-fastest Pakistan pacer to 50 Test wickets, in 10 Tests.
#
# Waqar Younis, Shabbir Ahm… https://t.co/bC1KIDHeya
#
# Fakhar Zaman became the fourth Pakistan player to get out in 90s on Test debut.
#
# https://t.co/qBlzEfZNKh
#
# #PakvAus
#
# Nathan Lyon is the first spinner in last 10 years to take 4 wickets in the first session on first day of a Test match.
#
# #PakvAus
#
# Nathan Lyon picks 4 wickets in 6 balls and goes past Mitchell Johnson to become the fourth-highest wicket-taker for… https://t.co/FaAWxEaP2N
#
# Most consecutive Test series wins at home:
#
# 10 Australia - 1994-2000
# 10 Australia - 2004-2008
# 10* India - 2013-*
#
# #IndvWI
#
# Umesh Yadav becomes only the third India fast bowler to take a 10 wickets in a Test at home!
#
# https://t.co/oTADZV9X5G
#
# #IndvWI
#
# Umesh Yadav's bowling strike rate this year is the best for any India fast bowler in a calendar year taking 15+ wkt… https://t.co/E24qdrs2uU
#
# First time since 2000 both openers of the visiting team have got out for ducks in the same innings in India.… https://t.co/LzW7PpA5gB
#
# Jason Holder's bowling average of 11.87 this year is the best for any fast bowler in a calendar year in last 100 ye… https://t.co/MERkCzo0Kk
#
# The 56-run lead by India is their lowest against West Indies in the 8 Tests since 2013.
#
# Leads in last 7 Tests v W… https://t.co/MFozyTFAnI
#
# Malinga has 8 five-wicket hauls in ODIs. Only four bowlers have more - https://t.co/ZyEiuNOXJY #SLvENG
#
# Most runs between dismissals for England in ODIs -
#
# JOE ROOT             304*
# Graeme Hick          301
# Jason Roy… https://t.co/KOguSh3n2k
#
# Bairstow is the sixth batsmen from England to score over 1000 runs in a year in ODIs- https://t.co/KZDCxzf7aE #SLvENG
#
# India batsmen to hit a six in the first over of a Test inns since 2000:
#
# Virender Sehwag v SA, Ahmedabad, 2008
#
# Pri… https://t.co/OsMrLkMMna
#
# Umesh Yadav's 6 for 88 is the first six-wkt haul by an India pacer at home since 2000.
#
# Lasr was Javagal Srinath v… https://t.co/BTQp9b4cVv
#
# Second ton for Roston Chase against India. Only 3 batsmen have scored more hundreds against India at No.6 position… https://t.co/gyRi0kDTAy
#
# Chase-Holder is the first pair to share 3 century partnerships for 7th wkt in Test history.
#
# https://t.co/TUcnHJYMOc
#
# #IndvWI
#
# First time in 3 years all of WI's top-8 batsmen got into double-figure scores.
#
# This is their first such instance… https://t.co/vC6hSZ0PnU
#
# West Indies' scores in India in last 2 Test series:
#
# 2013: 234, 168, 182, 187
# 2018: 181, 196 and now 150/5
#
# Only on… https://t.co/qh6dOLEXIQ
#
# Australia survive against Pakistan playing out 139.5 overs- Fourth longest fourth innings in Asia - https://t.co/QBojVVFgeZ #PAKvAUS
#
# RT @ESPNcricinfo: The records keep tumbling for Usman Khawaja in Dubai
#
# https://t.co/lpcpDZNOJo #PAKvAUS https://t.co/giup7m4KHn
#
# Australia now have the highest fourth innings score for a visiting team in the UAE going past the 322 made by Windi… https://t.co/edniE3EBnn
#
# Usman Khawaja has the highest score in the 4th innings in UAE going past the unbeaten 131 scored by Younis Khan in… https://t.co/tujflGmPdE
#
# Usman Khawaja is just the fifth player from Australia to score a fourth innings century in Asia -https://t.co/bnMrr09wLO #PAKvAUS
#
# First time in eight Tests a wicket hasn't fallen in the morning session on the fifth day in Dubai . #AUSvPAK
#
# The 132 runs added by Head &amp; Khawaja broke a couple of records
#
# 1) Highest 4th innings stand for Australia in Asia… https://t.co/slYJ9e1AXV
#
# First time in 20 years, Australia have had 4 or more ducks from top-6 batsmen in a Test.
#
# Head, Labushagne and Mar… https://t.co/oKUBDr2kSU
#
# 42 runs scored by Australia's Nos.3-11, the 3rd-lowest ever in their Test history, and their lowest in the 1st inni… https://t.co/2U1tRtXUbU
#
# Bilal Asif is the oldest to take a five-wicket haul on Test debut in the last 50 years.
#
# https://t.co/yV5Q8yI2yW
#
# #PakvAus
#
# Bilal Asif is the 11th Pakistan bowler to take a five-wicket haul on Test debut. https://t.co/dgpAVwwGh6
#
# #PakvAus
#
# Only the 6th instance in the last 100 years of two debutants in the top 6 getting ducks in an innings; 2 of them ha… https://t.co/b9Y74pg3aZ
#
# Australia's 142-run opening stand:
#
# - Their second-highest in Asia
# - Second-highest for any team v Pak in UAE
#
# #PakvAus
#
# Pakistan find the first wicket in the 52nd over.
#
# It was the first time in UAE that they had to wait more than 50… https://t.co/51trVr7KqI
#
# First century opening stand for Australia in Asia in about 4 years in 22 inns.
#
# Last was also in UAE, in Oct 2014… https://t.co/GRHpDqpVmD
#
# Only the second instance of century opening stands for both teams in their first inns in Tests in UAE.
#
# First was… https://t.co/OpTG44tq0I
#
# A 205 run opening stand between Hafeez and Imam - Fifth best opening stand for Pakistan and only the third instance… https://t.co/sw5XATPM5c
#
# In the last 10 years Australia have handed out caps to 51 players - Most by any team. The preceding 10 years saw Au… https://t.co/qR7YMdq19r
#
# RT @ESPNcricinfo: It's been quite the wait for Aaron Finch!
#
# https://t.co/YUIJjZDFjh #PAKvAUS
#
# (Note: Players from Afghanistan and Irelan…
#
# India players to win Man of the Match on their Test debut:
#
# Pravin Amre
# RP Singh
# R Ashwin
# Shikhar Dhawan
# Rohit Sharma
# PRITHVI SHAW
#
# #IndvWI
#
# The win by an innings &amp; 272 runs is India's biggest ever in Tests.
#
# https://t.co/Gi934BCjyc
#
# #IndvWI
#
# Five-wicket hauls in all 3 International formats:
#
# Tim Southee
# Lasith Malinga
# Ajanta Mendis
# B Kumar
# Umar Gul
# Imran… https://t.co/kBTMmTTP4c
#
# Lead of 468 runs is the third-highest first innings lead for India in Tests.
#
# https://t.co/H4imEQFrcf
#
# #IndvWI
#
# 649/9 is India's highest total against West Indies in Tests.
#
# https://t.co/cVDm8Ur7FW
#
# #IndvWI
#
# Bishoo has now conceded 180+ runs - the most by any West Indies bowler against India and fourth-most for WI in an i… https://t.co/A1uLW4rg5B
#
# Most 500+ totals at home since 2016:
#
# 8 India
# 4 Australia
# 2 Eng, NZ, SA
# 1 Bdesh
#
# #IndvWI
#
# Virat Kohli becomes the first India batsman to score 1000+ Test runs in three successive years.
#
# Only Hayden (5 ye… https://t.co/kOjprD2q8H
#
# Rishabh Pant missed becoming the first Indian wicketkeeper to score centuries in successive innings in Tests.
#
# #IndvWI
#
# Kohli is now the fourth-most century scorer for India in Tests, goes past Sehwag's 23 100s.
#
# Records page: https://t.co/3PIzHMFUUh
#
# #IndvWI
#
# 24 Test centuries for Kohli in 123 innings.
#
# Only Don Bradman got there in fewer inns (66).
#
# #IndvWI
#
# Prithvi Shaw becomes the youngest Indian and fourth youngest overall to score century on Test debut.
#
# https://t.co/eGt0ytCGuj
#
# #IndvWI
#
# Prithvi Shaw becomes the youngest Indian to score a fifty on Test debut.
#
# https://t.co/2u56iTKgkN
#
# #IndvWI
#
# No. of Test centuries:
# WI playing XI - 18
# Virat Kohli - 23
#
# No. of Test wickets:
# WI playing XI - 271
# R Ashwin - 327
#
# #IndvWI
#
# Prithvi Shaw is the youngest debutant (18y 329d) for India in Tests in last 10 years.
#
# https://t.co/BFI2h0ACtU
#
# #IndvWI
#
# The 223-run chase is the highest for India without an individual fifty-plus score.
#
# https://t.co/SgijlehKER
#
# #IndvBan #AsiaCup2018Final
#
# Mehidy Hasan Miraz becomes the first ever Bangladesh player to open the batting and bowling in an ODI.
#
# Last playe… https://t.co/O4ZMYHIikJ
#
# Bangladesh's innings:
#
# First 100 runs - 17.5 overs (107 balls)
#
# Next 100 runs - 26.5 overs (158 balls)
#
# #IndvBan #AsiaCupFinal
#
# Liton Das got to his century in the 29th over - the earliest any Bangladesh batsman has completed a century.
#
# Prev… https://t.co/AZM8Zu0sz7
#
# Liton Das' 33-ball fifty is the second-fastest against India in finals.
#
# Fastest is 32 balls by Symonds in 2003-04… https://t.co/sjr2KACeen
#
# Bangladesh have not won any knockout match in ODIs, before today.
#
# They have played five and lost all five. Two aga… https://t.co/4669PD6ibL
#
# Mushfiqur Rahim became the first Bangladesh batsman to get out on 99 in ODIs.
#
# He's also only the 7th wicketkeeper… https://t.co/BG4bIuSGZD
#
# India's 8th Tied result in ODIs and Afghanistan's first.
#
# https://t.co/HBibZpxw4o
#
# #IndvAfg #AsiaCup
#
# The 110-run opening stand between Rahul and Rayudu is the 100th century opening stand for India in ODIs - the first… https://t.co/TDvkAfCqZM
#
# Dhawan and Rohit's centuries are the 7th instance when both India openers have scored centuries and only the 2nd su… https://t.co/0x8aJqERqm
#
# Rohit Sharma became the fifth-fastest batsman to reach 7000 ODI runs.
#
# https://t.co/iPCAcxxWTp
#
# #IndvPak #AsiaCup
#
# 13 opening century stands for Rohit and Dhawan - Second most for India behind Sachin Tendulkar and Saurav Ganguly w… https://t.co/ADJPwcPYz7
#
# 22 runs off Bhuvneshwar's over - his most expensive over of ODI career.
#
# #AsiaCup #IndvPak
#
# Shoaib Malik is now the 4th highest run-getter in #AsiaCup. Only Jayasuriya, Sangakkara and Tendulkar have scored m… https://t.co/LYSi6iqrug
#
# Last time Pakistan finished a successful chase in the last over (50th over) was in Dec 2014.
#
# https://t.co/ZwTxlwNN71
#
# #AsiaCup #PakvAfg
#
# Bangladesh batsmen averaging under 18 this Asia Cup - their lowest in any series/tournament in four years.… https://t.co/iPIIvDvG8C
#
# The last time @imjadeja took three wickets in an ODI was way back in 2014 against West Indies. He has come back strongly. #AsiaCup
#
# In the last 35 ODIs Rashid Khan has gone wicketless only twice and averages 12.07 striking once every three overs. #AsiaCup
#
# This is India's best win while chasing against Pakistan - 126 balls remaining - https://t.co/p29aXpQemn #AsiaCup
#
# Pakistan's lowest score in the UAE this decade while batting first is 198 - They will need a special effort to get… https://t.co/q5fGz5eHcV
#
# First 100 run opening stand India have conceded in almost a year. Previous instance was when Australia  toured Indi… https://t.co/7TgH2FAzgl
#
# Pant and Rahul's partnership completes 200 runs.
#
# - Second ever for India in 4th inns
# - Second for any team for 6th wkt or lower
#
# #EngvInd
#
# Rishabh Pant is the youngest Indian to score a Test century since 2002.
#
# https://t.co/qq3bVgxHWQ
#
# #EngvInd
#
# The Rahul-Pant stand is the highest ever 6th wkt p'ship for India in 4th inns of Tests, beating the 136-run stand b… https://t.co/LEXpjRqBbQ
#
# Indian batsmen v Short &amp; Short good length deliveries in this 4th inns:
#
# Rahul - 32 off 30 balls
# Others - 11 off 22… https://t.co/c9Li6uX7by
#
# KL Rahul is only the second Indian opener to score a century in the 4th inns in England.
#
# Only one before this was… https://t.co/n8sxMYLb1q
#
# The partnership between Rahul and Rahane is only the second century stand for 4th wicket after a team being three-d… https://t.co/qprrNQ2TN4
#
# With a 7500-ball cut-off, only 2 England batsmen have faced more balls per dismissal since 1980 than Alastair Cook.… https://t.co/ArHcJjWTVD
#
# Lowest score at fall of 3rd wicket for India:
#
# 0 v Eng, Leeds, 1952
# 2 v NZ, Ahmedabad, 2010
# 2 v Eng, The Oval, 2018… https://t.co/12eFo5nxPh
#
# First time this year two England batsmen have scored 100s in the same Test innings, in 18 innings.
#
# https://t.co/Q1LSYwsdA8
#
# #EngvInd
#
# Alastair Cook becomes the most prolific run-getter among left-handed batsmen in Test cricket history, going past Ku… https://t.co/PwnYpULQ4v
#
# Alastair Cook is only the second player to scored 50+ in both innings of his debut Test and final Test.
#
# First was… https://t.co/XuCmkyz709
#
# Virat Kohli completes 4000 Test runs as captain - first Indian to do so and 10th overall.
#
# He's the fastest to ach… https://t.co/uPCh0s1O0Z
#
# Kohli completes 500 runs in the series.
#
# No one else has got to 300 even.
#
# https://t.co/RG6QaMrQyy
#
# #EngvInd
#
# Can India do it?
#
# https://t.co/xuruZ1G78f
#
# #EngvInd
#
# India batsmen average 18.74 in fourth innings in last two years, the lowest among all teams.
#
# https://t.co/VmpUSIScIX
#
# #EngvInd
#
# Curran's runs tally in this series is the highest by any player at No. 8 or lower in a series against India. Prev:… https://t.co/G5M0g3mcVb
#
# England lead over 200.
#
# The last time India successfully chased down 200 in Tests outside Asia was at Adelaide in… https://t.co/ClqjuWHyhv
#
# Alastair Cook's average has dropped below 45 for the first time in about 8 years.
#
# #EngvInd
#
# No. of partnerships of 30+ runs in this #EngvInd series:
#
# 1st &amp; 2nd wkts - 7 partnerships
# 9th &amp; 10th wkts - 8 partnerships
#
# #EngvInd
#
# Rishabh Pant's duck off 29 balls is the joint-longest duck for India in Tests. https://t.co/gV6nnam6DC
#
# #EngvInd
#
# Virat Kohli became the second-fastest India batsman to complete 6000 Test runs in 119 innings.
# https://t.co/YN0EGf58NK
# #EngvInd
#
# England lost 4 wkts for 36 runs - their 2nd-lowest score at fall of 4 wkts v India at home.
#
# https://t.co/kjm4IoFs0G
#
# #EngvInd
#
# Strike Rate of India's pace bowlers in this series is the best for any visiting team in England in over 100 years.… https://t.co/tzUDNeNJsQ
#
# 17.70 - Average of England's top-4 batsmen in this series - their worst in any series in last 80 years.
#
# #EngvInd
#
# Ishant Sharma got his 250th wicket in his 86th Test - the slowest among specialist bowlers.
#
# Kallis had taken 127… https://t.co/HserOjYAHT
#
# Incidentally, India's sequence of changing XIs began from the Southampton Test of 2014 and after 4 years at the sam… https://t.co/4iCsHxKyfr
#
# India are playing with an unchanged XI for the first time under Kohli's captaincy. #EngvAus
#
# India's win by 203 runs is only the sixth instance of a team winning by 200+ runs in the third Test after losing th… https://t.co/5AKLXYo5un
#
# The win by 203 runs is India's third-largest over England https://t.co/u6BElWtoqY
#
# #EngvInd
#
# Butter-Stokes' stand of 169 runs:
#
# - Highest for any team in 4th inns after being 4-down for &lt;100
# - Highest 5th wkt… https://t.co/Abg6XuVt41
#
# And that's England's biggest 5th-wkt partnership in the 4th innings in their Test history, going past a 65-year-old… https://t.co/LGjChEVoS5
#
# The Trent Bridge Test is the first ever Test in the history where the top-five batsmen reached double-figures in al… https://t.co/m4CkSjepqK
#
# The target for England in this Test will be the highest ever set by India against them.
#
# Previous: Target of 500 a… https://t.co/FisryCVN68
#
# Quickest to 23 Test centuries (inns):
#
# 59 Bradman
# 109 Gavaskar
# 110 S Smith
# 118 KOHLI
# 122 Yousuf
#
# #EngvInd
#
# 430* runs in this series for Kohli - the most by an Indian captain in a Test series in England, going past Azharudd… https://t.co/RzjQtM7Gm0
#
# Virat Kohli has been part of six of the last seven century partnerships for India in Tests in Eng/Aus/NZ/SA.
#
# #EngvInd
#
# 50+ opening partnerships for India in both innings of a Test in Eng/Aus/SA/NZ:
#
# Merchant-Mushtaq Ali, Oval, 1936
# En… https://t.co/JoUIgBsvxn
#
# First time since 1986 Indian openers have managed two 50+ partnerships in a Test in England/Australia/South Africa/… https://t.co/rzCJG1wcrC
#
# This is only the fourth ever instance where India have had two 50 plus opening stands in Australia, South Africa, E… https://t.co/faww3PnmVm
#
# Three times already teams have been bowled out within 50 overs in this series, which equals the most such instances… https://t.co/r7S5AzaEod
#
# England on Day 2:
#
# At Lunch: 46 for 0
# At Tea: 161 for 10
#
# #EngvInd
#
# First time since 2002 in a Test in England the top-six have all got to double-figures in the first innings of both… https://t.co/DZCdexkaaW
#
# 97 at Trent Bridge is only the second time Kohli has got out in the 90s in his Test career.
#
# The other was at Joha… https://t.co/8xs3bTAiXU
#
# Kohli-Rahane century stand:
#
# India's first in two tours this year (SA &amp; Eng)
#
# India's first since Bhuvneshwar-Shami's in 2014.
#
# #EngvInd
#
# First time since 2011 India's top-5 have all passed double-figures in an inns in England, i.e after 7 Tests and 14… https://t.co/Jsq5IFzSgz
#
# Average 1st-wkt stand in the first inns of a Trent Bridge Test in the last 10 matches before this one: 16 (highest… https://t.co/8j6MK7tGIe
#
# Rishabh Pant becomes the 5th youngest Indian wicket-keeper to make his debut in Tests.
#
# Parthiv Patel, Dinesh Kart… https://t.co/KdksD7H64I
#
# 33* - India's top score in this Test, their fifth-lowest in all result Tests for them: https://t.co/l3u7az6SIm #ENGvIND
#
# 4.77 - Ratio between Ind's bowling ave (56.57) and batting ave (11.85) in this Test... makes it into the top 10 of… https://t.co/zcx4qZ2hdn
#
# 4.77 - ratio between India's bowling ave (56.57) and their batting ave (11.85). Makes it into the top ten in terms… https://t.co/eEJvqfTxLa
#
# 18 runs by Indian openers in this Test is their lowest since Kingston 2006 https://t.co/X8nOjJghgi
#
# #EngvInd
#
# Anderson has become the first fast bowler and only the second after Muralitharan to take 100 Test wickets at a venu… https://t.co/qAqPtmUrmd
#
# Pairs by openers at Lord's:
#
# A Bannerman, 1988
# C Roach, 1933
# J McGlew, 1955
# J Wright, 1986
# Saleem Elahi, 2001
# M VIJAY, 2018
#
# #EngvInd
#
# England's results at Lord's after taking first innings lead of &gt;200:
#
# Won 26
# Drawn 6
# Lost 0
#
# #EngvInd
#
# Totals of teams batting first at Lord's in 3 recent Tests:
#
# 123 WIndies, 2017 (57.3) - Lost
# 184 Eng v Pak, 2018 (58… https://t.co/LVx6fBFlT4
#
# 11th time Kohli has scored 200 or more runs in a Test match, most among Indians. Tendulkar and Dravid did it 10 times.
#
# #EngvInd
#
# Vijay's 2nd-inngs problems continue: he averages 51.48 in the 1st innings, and 25 in the 2nd. In his last 10 second… https://t.co/Cj4KxS3Yju
#
# Since the start of 2014, Ishant has 72 wkts from 19 away Tests, the most wkts by an India bowler. Average less than… https://t.co/Wt7m6rUHiQ
#
# Ishant Sharma is the first Indian since Kumble at Adelaide in 2003 to take 3 wickets in an over outside Asia.
#
# #EngvInd
#
# Six wickets this Test is already the most Ashwin has taken in a Test in Eng/Aus/SA/NZ.
#
# #EngvInd
#
# Ashwin v left-handers: 169 wkts, ave 19.37; v right-handers: 153 wickets, ave 31.36 #ENGvIND
#
# 15th century as captain for Kohli.
#
# Only Graeme Smith (25) and Ponting (19) have more.
#
# https://t.co/neK9tqePLk
#
# #EngvInd
#
# Kohli's control % in the 2014 series in Eng: 80.5%; his control % in this innings: 75.6%. Yet, in 2014 he scored 13… https://t.co/0GtXOUsXfO
#
# Kohli gets past 40, his highest score in Tests in England.
#
# He averaged just 13.40 in the 2014 England tour with highest of 39.
#
# #EngvInd

# %% [markdown]
# # Find  the deals in the BestBuy_Deal tweets  that match products in SmartPortables MySQL product table

# %%
import re
import pymysql

cnx = pymysql.connect(user='root', password='deepak',
                              host='127.0.0.1',
                              database='csp584proj')
cursor = cnx.cursor()

query = ("SELECT playerName FROM players")
cursor.execute(query)


dealMatchGauranteed=[]
for product in cursor:
    for tweet in timeline:
        deal = (tweet['text'])
        if (len(re.findall('\s'+product[0]+'\s',deal)) >= 1):
            dealMatchGauranteed = dealMatchGauranteed + [deal]

# %%
# Sanity Test that  we got some deals
dealMatchGauranteed[:5]
# Out:
# ['Fastest to 21 ODI 100s:\n\n116 H Amla\n138 V Kohli\n183 AB de Villiers\n186 ROHIT SHARMA\n200 S Tendulkar\n\n#IndvWI',
#  'Fastest to 20 ODI 100s:\n\n108 H Amla\n133 V Kohli\n175 AB de Villiers\n183 ROHIT SHARMA\n197 S Tendulkar\n\n#IndvWI',
#  'Faf du Plessis and David Miller put together the third-highest partnership for South Africa in ODIs… https://t.co/mx8WTqpQtD',
#  '5th 200+ partnership between Virat Kohli and Rohit Sharma. No other pair has more than 3. \n\nhttps://t.co/y7frz177gy\n\n#IndvWI',
#  'No. of Test centuries:\nWI playing XI - 18\nVirat Kohli - 23\n\nNo. of Test wickets:\nWI playing XI - 271\nR Ashwin - 327\n\n#IndvWI']

# %% [markdown]
# # Create and write the deals into DealMatches.txt file that will be used by web-app of SmartPortables to display two deal matches

# %%
dealMatchFile = open(r'C:\apache-tomcat-7.0.34\webapps\CricInfo\DealMatches.txt', 'w')

for deal in dealMatchGauranteed:
  dealMatchFile.write("%s\n" % deal)

dealMatchFile.close()
